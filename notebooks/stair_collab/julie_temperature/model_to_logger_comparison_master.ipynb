# %%
import numpy as np
import xarray as xr
import pandas as pd
from salishsea_tools import viz_tools
import matplotlib.pyplot as plt
import matplotlib as mpl
import cmocean.cm as cm

# %% [markdown]
# # Data Import

# %%
temp_logged = pd.read_csv('/ocean/cdonaldson/MOAD/analysis-cassidy/notebooks/stair_collab/julie_temperature/Temp_data_high_tide_combined.csv')

# %%
temp_logged
# Out:
#        Water_level_m          Date_UTC  Mean_temp_C            Site  \
# 0              3.148  2024-03-19 15:00     8.971429  Cain_peninsula
# 1              3.575  2024-03-19 16:00     9.100000  Cain_peninsula
# 2              3.850  2024-03-19 17:00     9.171429  Cain_peninsula
# 3              3.949  2024-03-19 18:00     9.371429  Cain_peninsula
# 4              3.883  2024-03-19 19:00     9.471429  Cain_peninsula
# ...              ...               ...          ...             ...
# 23314          3.464  2024-09-17 14:00    14.750000     Sharon_cove
# 23315          3.365  2024-09-17 14:10    14.800000     Sharon_cove
# 23316          3.272  2024-09-17 14:20    14.800000     Sharon_cove
# 23317          3.163  2024-09-17 14:30    14.883333     Sharon_cove
# 23318          3.056  2024-09-17 14:40    14.916667     Sharon_cove
#
#              Lat         Lon
# 0      48.879148 -123.312558
# 1      48.879148 -123.312558
# 2      48.879148 -123.312558
# 3      48.879148 -123.312558
# 4      48.879148 -123.312558
# ...          ...         ...
# 23314  49.339260 -123.223257
# 23315  49.339260 -123.223257
# 23316  49.339260 -123.223257
# 23317  49.339260 -123.223257
# 23318  49.339260 -123.223257
#
# [23319 rows x 6 columns]

# %%
site_coords = temp_logged.set_index('Site')[['Lat', 'Lon']].drop_duplicates().to_dict('index')

# %%
bathy = xr.open_dataset('/home/sallen/MEOPAR/grid/bathymetry_202108.nc')
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask202108.nc')
tmask = 1 - mesh.tmask[0]

# %%
model_cain = xr.open_dataset('/ocean/cdonaldson/stair_extractions/julie/SalishSeaCast_hourly_phys_00_05_cain_20240319_20240926.nc')
model_heron = xr.open_dataset('/ocean/cdonaldson/stair_extractions/julie/SalishSeaCast_hourly_phys_00_05_heron_20240406_20240904.nc')

# %% [markdown]
# # Functions

# %%
def grid_from_latlon(lat_coord, lon_coord):
    lat_diff = np.abs(bathy.nav_lat - lat_coord)
    lon_diff  = np.abs(bathy.nav_lon - lon_coord)
    sum_of_diff = lat_diff + lon_diff
    intersect_idx = np.unravel_index(np.nanargmin(np.ma.masked_array(sum_of_diff, mask=tmask[5]).filled(np.nan)), sum_of_diff.shape)

    fig, ax = plt.subplots(1,2)
    cb = ax[0].pcolormesh(sum_of_diff)
    ax[0].set_ylabel('GridY')
    ax[0].set_xlabel('GridX')
    viz_tools.set_aspect(ax[0]);
    
    cb2 = ax[1].pcolormesh(np.ma.masked_array(sum_of_diff, mask=tmask[5]))
    ax[1].set_ylabel('GridY')
    ax[1].set_xlabel('GridX')
    viz_tools.set_aspect(ax[1]);
    ax[1].plot(intersect_idx[1], intersect_idx[0], 'r*')

    fig.colorbar(cb, ax=ax[:], label='Lat Diff + Lon Diff')

    print('(y, x): {}'.format(intersect_idx))
    print('Bathy: {} m'.format(bathy['Bathymetry'].isel(y=intersect_idx[0], x=intersect_idx[1]).values))

# %%
def plot_water_levels(site_name):
    temp_logged_site = temp_logged[temp_logged['Site'] == site_name]
    temp_logged_site['time'] = pd.to_datetime(temp_logged_site['Date_UTC'], format='%Y-%m-%d %H:%M')

    fig, ax = plt.subplots(1,1)
    ax.plot(temp_logged_site['time'], temp_logged_site['Water_level_m'], '-')
    print(temp_logged_site['time'].min())
    print(temp_logged_site['time'].max())
    print(len(temp_logged_site['time']))

    return temp_logged_site

# %%
def plot_temp_ts(temp_logged_site):

    fig, ax = plt.subplots(1,1)
    ax.plot(temp_logged_site['time'], temp_logged_site['Mean_temp_C'], '-')
    print(temp_logged_site['Mean_temp_C'].min())
    print(temp_logged_site['Mean_temp_C'].max())

# %%
def bias(obs, mod):
    return np.mean(mod - obs)

# %%
def rmse(obs, mod):
    return (np.sqrt(((mod - obs)**2).mean()))

# %% [markdown]
# # Work

# %%
site_names = temp_logged['Site'].unique()
print(site_names)
# Out:
# ['Cain_peninsula' 'Heron_rocks' 'Heriot_bay' 'Dinner_bay' 'Halfmoon_bay'
#  'Sharon_cove']

# %%
for site_name in site_names:    
    lat, lon = site_coords[site_name].values()
    plt.plot(lat, lon, 'ko')

# %% [markdown]
# ## Cain Penninsula

# %%
site_name = 'Cain_peninsula'
lat, lon = site_coords[site_name].values()
print(site_name)
grid_from_latlon(lat, lon)
temp_logged_cain = plot_water_levels(site_name)
plot_temp_ts(temp_logged_cain)
# temp_logged_cain.loc[temp_logged_cain['Mean_temp_C'] >= 20, 'Mean_temp_C'] = np.nan
temp_logged_cain.loc[temp_logged_cain['Mean_temp_C'].diff().abs() > 5, 'Mean_temp_C'] = np.nan
plot_temp_ts(temp_logged_cain)
# Out:
# Cain_peninsula
# (y, x): (384, 263)
# Bathy: 19.75 m
# 2024-03-19 15:00:00
# 2024-09-26 13:00:00
# 992
# 6.1
# 40.78333333
# 6.1
# 37.85714286
# /tmp/ipykernel_3315817/1811648375.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_logged_site['time'] = pd.to_datetime(temp_logged_site['Date_UTC'], format='%Y-%m-%d %H:%M')

# %%
times_cain = temp_logged_cain['time'].unique()
model_cain_filt_time = model_cain.sel(time=times_cain, method='nearest', tolerance='30min')  # because the model is at the half-hour and the logger is at the hour

# %%
mean_logged_lvl_cain = temp_logged_cain['Water_level_m'].mean()
print(mean_logged_lvl_cain)
model_cain_filt_time_depmean = model_cain_filt_time.sel(depth=mean_logged_lvl_cain, method='nearest')
model_cain_depmean = model_cain.sel(depth=mean_logged_lvl_cain, method='nearest')
# Out:
# 3.5133114919354838

# %%
fig, ax = plt.subplots(1,1, figsize=(11, 4))
ax.plot(model_cain_depmean.time, model_cain_depmean.votemper[:,:,0], label='model (depmean)')
# ax.plot(model_cain.time, model_cain.votemper[:,0,0,0], label='model (0)')
# ax.plot(model_cain.time, model_cain.votemper[:,4,0,0], label='model (4.5)')
ax.plot(temp_logged_cain['time'], temp_logged_cain['Mean_temp_C'],'.', markersize=2, color='k', label='logger')
ax.set_ylabel(r'Temperature [$^\circ$C]')
ax.set_title('Timeseries of Model and Logger Temperature (Filtered): {}'.format(site_name))
ax.legend()

# %%
cmap = cm.thermal
fig, ax = plt.subplots(1,1, figsize=(11, 2))
colors = ax.pcolormesh(model_cain_filt_time.reindex_like(model_cain).time, model_cain_filt_time.reindex_like(model_cain).depth, model_cain_filt_time.reindex_like(model_cain).votemper[:,:,0,0].T, cmap=cmap)
ax.set_ylim([5,0])
ax.set_title('Modeled Temperature (Filtered): {}'.format(site_name))
ax.set_ylabel('Depth [m]')
cb = fig.colorbar(colors, ax=ax, label=r'Temperature [$^\circ$C]', orientation='vertical')

# %%
cmap = cm.thermal
fig, ax = plt.subplots(1,1, figsize=(11, 2))
colors = ax.pcolormesh(model_cain.time, model_cain.depth, model_cain.votemper[:,:,0,0].T, cmap=cmap)
ax.set_ylim([5,0])
ax.set_title('Modeled Temperature: {}'.format(site_name))
ax.set_ylabel('Depth [m]')
cb = fig.colorbar(colors, ax=ax, label=r'Temperature [$^\circ$C]', orientation='vertical')

# %%
#  obs, mod
diff_cain = model_cain_filt_time_depmean.votemper[:,0,0].values - temp_logged_cain['Mean_temp_C']
bias_cain = bias(temp_logged_cain['Mean_temp_C'], model_cain_filt_time_depmean.votemper[:,0,0].values)
rmse_cain = rmse(temp_logged_cain['Mean_temp_C'], model_cain_filt_time_depmean.votemper[:,0,0].values)

# %%
fig, ax = plt.subplots(1,1, figsize=(11, 4))
ax.plot(temp_logged_cain['time'], diff_cain,'.', markersize=2, color='k', label='residuals')
ax.hlines(0, temp_logged_cain['time'].min(), temp_logged_cain['time'].max(), color='r', zorder=0)
ax.set_ylabel(r'Temperature [$^\circ$C]')
ax.set_title('Timeseries of Model and Logger Temperature (Filtered): {}\nBias: {}\nRMSE: {}'.format(site_name, bias_cain, rmse_cain))
ax.legend()

# %% [markdown]
# ## Heron Rocks

# %%
site_name = 'Heron_rocks'
lat, lon = site_coords[site_name].values()
print(site_name)
grid_from_latlon(lat, lon)
temp_logged_heron = plot_water_levels(site_name)
plot_temp_ts(temp_logged_heron)
# temp_logged_heron.loc[temp_logged_heron['Mean_temp_C'] >= 20, 'Mean_temp_C'] = np.nan
temp_logged_heron.loc[temp_logged_heron['Mean_temp_C'].diff().abs() > 5, 'Mean_temp_C'] = np.nan
plot_temp_ts(temp_logged_heron)
# Out:
# Heron_rocks
# (y, x): (599, 141)
# Bathy: 19.1875 m
# 2024-04-06 09:30:00
# 2024-09-04 15:30:00
# 2276
# 8.8
# 22.65
# 8.8
# 22.65
# /tmp/ipykernel_3315817/1811648375.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_logged_site['time'] = pd.to_datetime(temp_logged_site['Date_UTC'], format='%Y-%m-%d %H:%M')

# %%
times_heron = temp_logged_heron['time'].unique()
model_heron_filt_time = model_heron.sel(time=times_heron, method='nearest', tolerance='30min')  # because the model is at the half-hour and the logger is at the hour

# %%
mean_logged_lvl_heron = temp_logged_heron['Water_level_m'].mean()
print(mean_logged_lvl_heron)
model_heron_filt_time_depmean = model_heron_filt_time.sel(depth=mean_logged_lvl_heron, method='nearest')
model_heron_depmean = model_heron.sel(depth=mean_logged_lvl_heron, method='nearest')
# Out:
# 4.070731985940246

# %%
fig, ax = plt.subplots(1,1, figsize=(11, 4))
ax.plot(model_heron_depmean.time, model_heron_depmean.votemper[:,:,0], label='model (depmean)')
ax.plot(model_heron.time, model_heron.votemper[:,0,0,0], label='model (0)')
# ax.plot(model_heron.time, model_heron.votemper[:,4,0,0], label='model (4.5)')
ax.plot(temp_logged_heron['time'], temp_logged_heron['Mean_temp_C'],'.', markersize=2, color='k', label='logger')
ax.set_ylabel(r'Temperature [$^\circ$C]')
ax.set_title('Timeseries of Model and Logger Temperature (Filtered): {}'.format(site_name))
ax.legend()

# %%
cmap = cm.thermal
fig, ax = plt.subplots(1,1, figsize=(11, 2))
colors = ax.pcolormesh(model_heron_filt_time.reindex_like(model_heron).time, model_heron_filt_time.reindex_like(model_heron).depth, model_heron_filt_time.reindex_like(model_heron).votemper[:,:,0,0].T, cmap=cmap)
ax.set_ylim([5,0])
ax.set_title('Modeled Temperature (Filtered): {}'.format(site_name))
ax.set_ylabel('Depth [m]')
cb = fig.colorbar(colors, ax=ax, label=r'Temperature [$^\circ$C]', orientation='vertical')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [26], line 3
#       1 cmap = cm.thermal
#       2 fig, ax = plt.subplots(1,1, figsize=(11, 2))
# ----> 3 colors = ax.pcolormesh(model_heron_filt_time.reindex_like(model_heron).time, model_heron_filt_time.reindex_like(model_heron).depth, model_heron_filt_time.reindex_like(model_heron).votemper[:,:,0,0].T, cmap=cmap)
#       4 ax.set_ylim([5,0])
#       5 ax.set_title('Modeled Temperature (Filtered): {}'.format(site_name))
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/dataset.py:2893, in Dataset.reindex_like(self, other, method, tolerance, copy, fill_value)
#    2836 def reindex_like(
#    2837     self: T_Dataset,
#    2838     other: Dataset | DataArray,
#    (...)
#    2842     fill_value: Any = xrdtypes.NA,
#    2843 ) -> T_Dataset:
#    2844     """Conform this object onto the indexes of another object, filling in
#    2845     missing values with ``fill_value``. The default fill value is NaN.
#    2846
#    (...)
#    2891     align
#    2892     """
# -> 2893     return alignment.reindex_like(
#    2894         self,
#    2895         other=other,
#    2896         method=method,
#    2897         tolerance=tolerance,
#    2898         copy=copy,
#    2899         fill_value=fill_value,
#    2900     )
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/alignment.py:917, in reindex_like(obj, other, method, tolerance, copy, fill_value)
#     911             if other_size != obj_size:
#     912                 raise ValueError(
#     913                     "different size for unlabeled "
#     914                     f"dimension on argument {dim!r}: {other_size!r} vs {obj_size!r}"
#     915                 )
# --> 917 return reindex(
#     918     obj,
#     919     indexers=other.xindexes,
#     920     method=method,
#     921     tolerance=tolerance,
#     922     copy=copy,
#     923     fill_value=fill_value,
#     924 )
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/alignment.py:888, in reindex(obj, indexers, method, tolerance, copy, fill_value, sparse, exclude_vars)
#     869 # TODO: (benbovy - explicit indexes): uncomment?
#     870 # --> from reindex docstrings: "any mis-matched dimension is simply ignored"
#     871 # bad_keys = [k for k in indexers if k not in obj._indexes and k not in obj.dims]
#    (...)
#     875 #         "or unindexed dimension in the object to reindex"
#     876 #     )
#     878 aligner = Aligner(
#     879     (obj,),
#     880     indexes=indexers,
#    (...)
#     886     exclude_vars=exclude_vars,
#     887 )
# --> 888 aligner.align()
#     889 return aligner.results[0]
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/alignment.py:565, in Aligner.align(self)
#     563     self.override_indexes()
#     564 else:
# --> 565     self.reindex_all()
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/alignment.py:542, in Aligner.reindex_all(self)
#     541 def reindex_all(self) -> None:
# --> 542     self.results = tuple(
#     543         self._reindex_one(obj, matching_indexes)
#     544         for obj, matching_indexes in zip(
#     545             self.objects, self.objects_matching_indexes
#     546         )
#     547     )
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/alignment.py:543, in <genexpr>(.0)
#     541 def reindex_all(self) -> None:
#     542     self.results = tuple(
# --> 543         self._reindex_one(obj, matching_indexes)
#     544         for obj, matching_indexes in zip(
#     545             self.objects, self.objects_matching_indexes
#     546         )
#     547     )
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/alignment.py:527, in Aligner._reindex_one(self, obj, matching_indexes)
#     521 def _reindex_one(
#     522     self,
#     523     obj: DataAlignable,
#     524     matching_indexes: dict[MatchingIndexKey, Index],
#     525 ) -> DataAlignable:
#     526     new_indexes, new_variables = self._get_indexes_and_vars(obj, matching_indexes)
# --> 527     dim_pos_indexers = self._get_dim_pos_indexers(matching_indexes)
#     529     new_obj = obj._reindex_callback(
#     530         self,
#     531         dim_pos_indexers,
#    (...)
#     536         self.exclude_vars,
#     537     )
#     538     new_obj.encoding = obj.encoding
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/alignment.py:493, in Aligner._get_dim_pos_indexers(self, matching_indexes)
#     491     if obj_idx is not None:
#     492         if self.reindex[key]:
# --> 493             indexers = obj_idx.reindex_like(aligned_idx, **self.reindex_kwargs)  # type: ignore[call-arg]
#     494             dim_pos_indexers.update(indexers)
#     496 return dim_pos_indexers
#
# File ~/conda_envs/analysis-cassidy/lib/python3.10/site-packages/xarray/core/indexes.py:509, in PandasIndex.reindex_like(self, other, method, tolerance)
#     505 def reindex_like(
#     506     self, other: PandasIndex, method=None, tolerance=None
#     507 ) -> dict[Hashable, Any]:
#     508     if not self.index.is_unique:
# --> 509         raise ValueError(
#     510             f"cannot reindex or align along dimension {self.dim!r} because the "
#     511             "(pandas) index has duplicate values"
#     512         )
#     514     return {self.dim: get_indexer_nd(self.index, other.index, method, tolerance)}
#
# ValueError: cannot reindex or align along dimension 'time' because the (pandas) index has duplicate values

# %%
cmap = cm.thermal
fig, ax = plt.subplots(1,1, figsize=(11, 2))
colors = ax.pcolormesh(model_heron.time, model_heron.depth, model_heron.votemper[:,:,0,0].T, cmap=cmap)
ax.set_ylim([5,0])
ax.set_title('Modeled Temperature: {}'.format(site_name))
ax.set_ylabel('Depth [m]')
cb = fig.colorbar(colors, ax=ax, label=r'Temperature [$^\circ$C]', orientation='vertical')

# %%
#  obs, mod
diff_heron = model_heron_filt_time_depmean.votemper[:,0,0].values - temp_logged_heron['Mean_temp_C']
bias_heron = bias(temp_logged_heron['Mean_temp_C'], model_heron_filt_time_depmean.votemper[:,0,0].values)
rmse_heron = rmse(temp_logged_heron['Mean_temp_C'], model_heron_filt_time_depmean.votemper[:,0,0].values)

# %%
fig, ax = plt.subplots(1,1, figsize=(11, 4))
ax.plot(temp_logged_heron['time'], diff_heron,'.', markersize=2, color='k', label='residuals')
ax.hlines(0, temp_logged_heron['time'].min(), temp_logged_heron['time'].max(), color='r', zorder=0)
ax.set_ylabel(r'Temperature [$^\circ$C]')
ax.set_title('Timeseries of Model and Logger Temperature (Filtered): {}\nBias: {}\nRMSE: {}'.format(site_name, bias_heron, rmse_heron))
ax.legend()

# %% [markdown]
# ## Heriot Bay

# %%
site_name = 'Heriot_bay'
lat, lon = site_coords[site_name].values()
print(site_name)
grid_from_latlon(lat, lon)
plot_water_levels(site_name)
# Out:
# Heriot_bay
# (y, x): (761, 137)
# Bathy: 15.25 m
# 2024-07-10 02:00:00
# 2024-07-30 23:30:00
# /tmp/ipykernel_1854567/3518042275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_logged_site['time'] = pd.to_datetime(temp_logged_site['Date_UTC'], format='%Y-%m-%d %H:%M')

# %% [markdown]
# ## Dinner Bay

# %%
site_name = 'Dinner_bay'
lat, lon = site_coords[site_name].values()
print(site_name)
grid_from_latlon(lat, lon)
plot_water_levels(site_name)
# Out:
# Dinner_bay
# (y, x): (377, 256)
# Bathy: 39.0625 m
# 2024-03-20 09:00:00
# 2024-09-27 08:30:00
# /tmp/ipykernel_1854567/3518042275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_logged_site['time'] = pd.to_datetime(temp_logged_site['Date_UTC'], format='%Y-%m-%d %H:%M')

# %% [markdown]
# ## Halfmoon Bay

# %%
site_name = 'Halfmoon_bay'
lat, lon = site_coords[site_name].values()
print(site_name)
grid_from_latlon(lat, lon)
plot_water_levels(site_name)
# Out:
# Halfmoon_bay
# (y, x): (551, 249)
# Bathy: 27.8125 m
# 2024-05-29 09:00:00
# 2024-09-15 11:30:00
# /tmp/ipykernel_1854567/3518042275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_logged_site['time'] = pd.to_datetime(temp_logged_site['Date_UTC'], format='%Y-%m-%d %H:%M')

# %% [markdown]
# ## Sharon Cove
# No Google Maps result

# %%
site_name = 'Sharon_cove'
lat, lon = site_coords[site_name].values()
print(site_name)
grid_from_latlon(lat, lon)
plot_water_levels(site_name)
# Out:
# Sharon_cove
# (y, x): (468, 334)
# Bathy: 9.5625 m
# 2024-03-01 02:00:00
# 2024-09-17 14:40:00
# /tmp/ipykernel_1854567/3518042275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_logged_site['time'] = pd.to_datetime(temp_logged_site['Date_UTC'], format='%Y-%m-%d %H:%M')
