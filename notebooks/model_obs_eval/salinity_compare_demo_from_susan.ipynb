# %%
import cmocean.cm as cm
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd
import statsmodels.api as sm
import xarray as xr

from salishsea_tools import viz_tools

# %% [markdown]
# DFO data from 2013- Mar 2020
#
# PSF data from 2015- 2017
#
# PUG data from 2015- 2018
#
# ONC data from 2014- 2022 Ferry data from 2013- 2022

# %%
field = 'Salinity'
obsn = 'SA'
modn = 'mod_vosaline'
vmax = 34
vmin = 0
dbin = 0.5
scale = 24

cmap = cm.rain #'pink_r'#cm.rain #cm.ice_r #'ocean_r' #'pink_r'

# %%
foramt = "{:.3}"
myformat = {'bias': foramt, 'rmse': foramt, 'crmse':foramt, 'swillmott': foramt, 'slopedev': foramt, 'const': foramt,
                         'systematic': foramt, 'nonsystematic':foramt, 
                    'spread': foramt}

def use_f_2(x):
    return "%.2f" % x

# %%
with xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc') as mesh:
    deptht = mesh.gdept_1d[0].values
bathy = xr.open_dataset('/home/sallen/MEOPAR/grid/bathymetry_202108.nc')

# %%
def bias(df, obs, mod):
    diffy = df[mod] - df[obs]
    return diffy.count(), diffy.mean()

# %%
def rmse(df, obs, mod):
    return (np.sqrt(((df[mod] - df[obs])**2).mean()))

# %%
def crmse(rmse, bias):
    return (np.sqrt(rmse**2 - bias**2))

# %%
def swillmott(df, obs, mod):
    meanobs = df[obs].mean()
    return (((df[mod] - df[obs])**2).sum()
            /(( (df[mod] - meanobs).abs() + (df[obs] - meanobs).abs() )**2).sum())

# %%
def slope_inter(df, obs, mod):
    X = df[obs]
    y = df[mod]
    X = sm.add_constant(X)

    # Fit and make the predictions by the model
    model = sm.OLS(y, X, missing='drop').fit()
#    print (model.summary())
    predictions = model.predict(X)
    
    nonsyst = np.sqrt(((y - predictions)**2).mean())
    systematic = np.sqrt(((predictions - df[obs])**2).mean())
    return model.params[obs], model.params['const'], systematic, nonsyst

# %%
def wolfram_perp(df, obsin, modin):
    
    mod = np.array(df[modin][(df[modin] == df[modin]) & (df[obsin] == df[obsin])])
    obs = np.array(df[obsin][(df[modin] == df[modin]) & (df[obsin] == df[obsin])])
    
    n = mod.shape[0]

    y2s = (mod**2).sum()
    ys = mod.sum()
    x2s = (obs**2).sum()
    xs = obs.sum()
    xys = (mod * obs).sum()
    B = 0.5 * ( (y2s - ys**2/n) - (x2s - xs**2/n)) / (xs * ys/n - xys)
    b1 = -B + np.sqrt(B*B + 1)
    a1 = (ys - b1*xs)/n
    predictions = a1 + b1 * df[obsin]
    
    nonsyst = np.sqrt(((df[modin] - predictions)**2).mean())
    systematic = np.sqrt(((predictions - df[obsin])**2).mean())
  
    return a1, b1, systematic, nonsyst

# %%
def spread(df, obs, mod):
    return 1 - ((df[mod] - df[mod].mean())**2).mean() / ((df[obs] - df[obs].mean())**2).mean()

# %%
def read_pieces(pieces):
    temp1 = pd.read_csv(pieces[0])
    for piece in pieces[1:]:
        nextpiece = pd.read_csv(piece)
        if 'ferry' in piece:
            nextpiece['k'] = 0
        temp1 = pd.concat([temp1, nextpiece], ignore_index=True)
#    temp1['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
    return temp1

# %%
def filter_bad_data(temp1):
# bad data in Puget Sound (pugts)
    temp1_nohook = temp1[(temp1.Lat > 47.30) | (temp1.Lon < -122.5) | (temp1.Z < 5) | (temp1.SA > 26) ]
# bad onc data
 #   temp1_nobox_nohook = temp1_nohook[(temp1_nohook['depth (m)'] != 107) | (temp1_nohook.SA > 29)]
# bad ferry data
  #  temp1_clean = temp1_nobox_nohook[((temp1_nobox_nohook.SA > 0.2) | (temp1_nobox_nohook.mod_vosaline - temp1_nobox_nohook.SA < 20)) 
  #                                   & ((temp1_nobox_nohook.Lon > -123.8) | (temp1_nobox_nohook.SA > 14))]
    return temp1_nohook

# %%
def plot_and_stats(temp1, name, idepth, jdepth, fig, ax, whichdepths, reverse, string, boxes=False, box=None, boxname=None):
    print (temp1[temp1.k <= idepth])
    if boxes:
        corn = box
        select = temp1[(temp1.k >= idepth) & (temp1.k <= jdepth) &
                              (temp1.j >= corn[0]) & (temp1.j <= corn[1]) &
                              (temp1.i >= corn[2]) & (temp1.i <= corn[3])]
        shift_text = 0.94
    else:
        select = temp1[(temp1.k >= idepth) & (temp1.k < jdepth)]
        shift_text = 1
    
    print (swillmott(select, 'SA', 'mod_vosaline'))
    
    if reverse:
        one = modn
        two = obsn
    else:
        one = obsn
        two = modn
    
    counts, xedges, yedges, color = ax.hist2d(select[one], 
                                              select[two], 
                                           bins=np.arange(vmin, vmax, dbin), norm=LogNorm(), cmap=cmap);
    fig.colorbar(color, ax=ax)
   
    number, tbias = bias(select, one, two)
    trmse = rmse(select, one, two)
    tcrmse = crmse(trmse, tbias)
    tswillmott = swillmott(select, one, two)
#    m, c, syst, nonsyst = slope_inter(select, one, two)
    a1, b1, syst, nonsyst = wolfram_perp(select, one, two)
    tspread = spread(select, one, two)
    ax.plot([vmin, vmax], [vmin, vmax], 'k-');
    xr = np.arange(vmin, vmax, 0.5)
#    ax.plot(xr, c + m * xr, 'r-');
    ax.plot(xr, a1 + b1 * xr, 'r-')
    sc = scale/12
    sh = 2*sc-1
    bot = scale
    top = bot + 2*sh
    ax.arrow(sc+vmin, bot+vmin, 0, sh-np.abs(tbias)/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(sc+vmin, top+vmin, 0, -sh+np.abs(tbias)/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(2*sc+vmin, bot+vmin, 0, sh-syst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(2*sc+vmin, top+vmin, 0, -sh+syst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(3*sc+vmin, bot+vmin, 0, sh-nonsyst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True)
    ax.arrow(3*sc+vmin, top+vmin, 0, -sh+nonsyst/2, head_width=0.5*sc, head_length=0.2*sc, length_includes_head=True);
    Cp2 = {'number': number,
            'bias': tbias,
          'rmse': trmse,
           'crmse': tcrmse,
          'swillmott': tswillmott,
          'slopedev': 1-b1,
          'const': a1,
          'systematic': syst,
          'nonsystematic': nonsyst,
          'spread': tspread}
    ax.text(0.8*sc+vmin, 0.9*bot*shift_text+vmin, 'bias', rotation=90)
    ax.text(1.8*sc+vmin, 0.72*bot*shift_text+vmin-shift_text, 'systematic', rotation=90)
    ax.text(2.8*sc+vmin, 0.6*bot*shift_text+vmin-shift_text, 'non-systematic', rotation=90)
    
    ax.set_title(f'{name}, {field} {whichdepths}{string}');
    dCp2 = pd.DataFrame(data=Cp2, index=[name])
    return dCp2, counts

# %%
def highlight_max_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''

    is_max = abs(s) == abs(s).max()
    is_min = abs(s) == abs(s).min()
    color = []
    for v, v2 in zip(is_max, is_min):
        if v:
            color.append('red')
        elif v2:
            color.append('darkgreen')
        else:
            color.append('black')
    return ['color: %s' % color[i] for i in range(len(is_max))]

# %%
def plot_allyears(years, years_psf, years_pug, years_onc, years_ferry, idepth, jdepth, whichdepths, reverse=False):
    if reverse:
        string = '_reverse'
    else:
        string = ''
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    startyear = min(years[0], years_psf[0], years_pug[0])#, years_onc[0])
    endyear = max(years[-1], years_psf[-1], years_pug[-1])#, years_onc[-1])
    fig.suptitle(f'Year {startyear}-{endyear}')
    print (idepth, jdepth)
    pieces1 = []
    for year in years:
        pieces1.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ctd_{year}0101_{year}1231.csv')
    for year in years_psf:
        pieces1.append(
            f'//data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_psfts_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_pugts_{year}0101_{year}1231.csv')
         #   f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_pugts_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ferry_{year}0101_{year}1231.csv')
    temp1 = read_pieces(pieces1)
    d201905, counts1 = plot_and_stats(filter_bad_data(temp1), '201905R', idepth, jdepth, fig, axs[0], whichdepths, reverse, string)
    
    pieces2 = []
    for year in years:
        pieces2.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ctd_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_psfts_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_pugts_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ferry_{year}0101_{year}1231.csv')
    temp2 = read_pieces(pieces2)
    d202111, counts2 = plot_and_stats(filter_bad_data(temp2), '202111', idepth, jdepth, fig, axs[1], whichdepths, reverse, string)

    alltogether = pd.concat([d201905, d202111], axis=0)
    
    fig.savefig(f'{whichdepths}_{field}{string}_201905_202111_for_allyears.png')
    
    f = open(f'./{whichdepths}_{field}{string}_201905_202111_for_allyears_table.tex', 'w')
    f.write(alltogether.to_latex(column_format='lcccccccccc', 
            formatters=[None, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2]))
    f.close()
    return alltogether, counts1, counts2

# %% [markdown]
# ## All Depths

# %%
idepth = 0
jdepth = 39

results, counts1, counts2 = plot_allyears([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
                                          , [2015, 2016, 2017]
                                          , [2015, 2016, 2017, 2018]
                                       , []#[2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
                                       , []#[2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
                                          , idepth, jdepth, 'alldepths')
results.style.format(myformat).apply(highlight_max_min)
# Out:
# 0 39
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1353           1353  2013.0    2.0  13.0  16.696111  49.318167 -123.934833
# 2895           2895  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 2896           2896  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 3533           3533  2013.0    3.0   7.0  16.628056  49.316500 -123.945667
# ...             ...     ...    ...   ...        ...        ...         ...
# 1586222       54755     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586223       54756     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586224       54757     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586225       54758     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586226       54759     NaN    NaN   NaN        NaN  47.213427 -123.077650
#
#                  Z         SA        CT  ...  o2SAT  o2uM  conductivity  \
# 0         0.892338  27.814801  6.753649  ...    NaN   NaN           NaN
# 1353      0.991488  28.529872  6.944525  ...    NaN   NaN           NaN
# 2895      0.297447  28.267852  7.220572  ...    NaN   NaN           NaN
# 2896      0.892339  28.304597  7.247064  ...    NaN   NaN           NaN
# 3533      0.495745  28.513321  7.378918  ...    NaN   NaN           NaN
# ...            ...        ...       ...  ...    ...   ...           ...
# 1586222   9.000000  27.275431  8.879109  ...    NaN   NaN           NaN
# 1586223   9.500000  27.274713  8.879375  ...    NaN   NaN           NaN
# 1586224  10.000000  27.274298  8.879233  ...    NaN   NaN           NaN
# 1586225  10.500000  27.276598  8.880462  ...    NaN   NaN           NaN
# 1586226  11.000000  27.281411  8.882865  ...    NaN   NaN           NaN
#
#         temperature  Station        Basin    Sigma  Chl  SiteCode  \
# 0               NaN      NaN          NaN      NaN  NaN       NaN
# 1353            NaN      NaN          NaN      NaN  NaN       NaN
# 2895            NaN      NaN          NaN      NaN  NaN       NaN
# 2896            NaN      NaN          NaN      NaN  NaN       NaN
# 3533            NaN      NaN          NaN      NaN  NaN       NaN
# ...             ...      ...          ...      ...  ...       ...
# 1586222         NaN   OAK004  South Basin  21.0087  NaN    OAK004
# 1586223         NaN   OAK004  South Basin  21.0082  NaN    OAK004
# 1586224         NaN   OAK004  South Basin  21.0079  NaN    OAK004
# 1586225         NaN   OAK004  South Basin  21.0095  NaN    OAK004
# 1586226         NaN   OAK004  South Basin  21.0129  NaN    OAK004
#
#          mod_dissolved_oxygen
# 0                         NaN
# 1353                      NaN
# 2895                      NaN
# 2896                      NaN
# 3533                      NaN
# ...                       ...
# 1586222                   NaN
# 1586223                   NaN
# 1586224                   NaN
# 1586225                   NaN
# 1586226                   NaN
#
# [43588 rows x 39 columns]
# 0.04026724275282319
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1353           1353  2013.0    2.0  13.0  16.696111  49.318167 -123.934833
# 2895           2895  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 2896           2896  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 3533           3533  2013.0    3.0   7.0  16.628056  49.316500 -123.945667
# ...             ...     ...    ...   ...        ...        ...         ...
# 1586222       54755     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586223       54756     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586224       54757     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586225       54758     NaN    NaN   NaN        NaN  47.213427 -123.077650
# 1586226       54759     NaN    NaN   NaN        NaN  47.213427 -123.077650
#
#                  Z         SA        CT  ...  chl  o2SAT  o2uM conductivity  \
# 0         0.892338  27.814801  6.753649  ...  NaN    NaN   NaN          NaN
# 1353      0.991488  28.529872  6.944525  ...  NaN    NaN   NaN          NaN
# 2895      0.297447  28.267852  7.220572  ...  NaN    NaN   NaN          NaN
# 2896      0.892339  28.304597  7.247064  ...  NaN    NaN   NaN          NaN
# 3533      0.495745  28.513321  7.378918  ...  NaN    NaN   NaN          NaN
# ...            ...        ...       ...  ...  ...    ...   ...          ...
# 1586222   9.000000  27.275431  8.879109  ...  NaN    NaN   NaN          NaN
# 1586223   9.500000  27.274713  8.879375  ...  NaN    NaN   NaN          NaN
# 1586224  10.000000  27.274298  8.879233  ...  NaN    NaN   NaN          NaN
# 1586225  10.500000  27.276598  8.880462  ...  NaN    NaN   NaN          NaN
# 1586226  11.000000  27.281411  8.882865  ...  NaN    NaN   NaN          NaN
#
#          temperature  Station        Basin    Sigma  Chl  SiteCode
# 0                NaN      NaN          NaN      NaN  NaN       NaN
# 1353             NaN      NaN          NaN      NaN  NaN       NaN
# 2895             NaN      NaN          NaN      NaN  NaN       NaN
# 2896             NaN      NaN          NaN      NaN  NaN       NaN
# 3533             NaN      NaN          NaN      NaN  NaN       NaN
# ...              ...      ...          ...      ...  ...       ...
# 1586222          NaN   OAK004  South Basin  21.0087  NaN    OAK004
# 1586223          NaN   OAK004  South Basin  21.0082  NaN    OAK004
# 1586224          NaN   OAK004  South Basin  21.0079  NaN    OAK004
# 1586225          NaN   OAK004  South Basin  21.0095  NaN    OAK004
# 1586226          NaN   OAK004  South Basin  21.0129  NaN    OAK004
#
# [43592 rows x 39 columns]
# 0.03242091776178518
# /tmp/ipykernel_2628431/714136494.py:56: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(alltogether.to_latex(column_format='lcccccccccc',
# <style type="text/css">
# #T_1c930_row0_col0, #T_1c930_row0_col1, #T_1c930_row0_col2, #T_1c930_row0_col3, #T_1c930_row0_col4, #T_1c930_row0_col5, #T_1c930_row0_col6, #T_1c930_row0_col7, #T_1c930_row0_col8, #T_1c930_row0_col9 {
#   color: red;
# }
# #T_1c930_row1_col0, #T_1c930_row1_col1, #T_1c930_row1_col2, #T_1c930_row1_col3, #T_1c930_row1_col4, #T_1c930_row1_col5, #T_1c930_row1_col6, #T_1c930_row1_col7, #T_1c930_row1_col8, #T_1c930_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_1c930">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c930_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_1c930_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_1c930_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_1c930_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_1c930_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_1c930_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_1c930_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_1c930_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_1c930_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_1c930_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c930_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_1c930_row0_col0" class="data row0 col0" >1546309</td>
#       <td id="T_1c930_row0_col1" class="data row0 col1" >0.0402</td>
#       <td id="T_1c930_row0_col2" class="data row0 col2" >0.566</td>
#       <td id="T_1c930_row0_col3" class="data row0 col3" >0.564</td>
#       <td id="T_1c930_row0_col4" class="data row0 col4" >0.0403</td>
#       <td id="T_1c930_row0_col5" class="data row0 col5" >-0.0702</td>
#       <td id="T_1c930_row0_col6" class="data row0 col6" >-2.08</td>
#       <td id="T_1c930_row0_col7" class="data row0 col7" >0.106</td>
#       <td id="T_1c930_row0_col8" class="data row0 col8" >0.576</td>
#       <td id="T_1c930_row0_col9" class="data row0 col9" >-0.135</td>
#     </tr>
#     <tr>
#       <th id="T_1c930_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_1c930_row1_col0" class="data row1 col0" >1546278</td>
#       <td id="T_1c930_row1_col1" class="data row1 col1" >0.0177</td>
#       <td id="T_1c930_row1_col2" class="data row1 col2" >0.502</td>
#       <td id="T_1c930_row1_col3" class="data row1 col3" >0.501</td>
#       <td id="T_1c930_row1_col4" class="data row1 col4" >0.0324</td>
#       <td id="T_1c930_row1_col5" class="data row1 col5" >-0.0366</td>
#       <td id="T_1c930_row1_col6" class="data row1 col6" >-1.09</td>
#       <td id="T_1c930_row1_col7" class="data row1 col7" >0.0539</td>
#       <td id="T_1c930_row1_col8" class="data row1 col8" >0.508</td>
#       <td id="T_1c930_row1_col9" class="data row1 col9" >-0.0717</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Top 5m

# %%
idepth = 0
jdepth = 5

results, counts1, counts2 = plot_allyears([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], [2015, 2016, 2017], 
                                          [2015, 2016, 2017, 2018], 
                                          [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022], 
                                          [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
                                          idepth, jdepth, 'top5m')
results.style.format(myformat).apply(highlight_max_min)
# Out:
# 0 5
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1353           1353  2013.0    2.0  13.0  16.696111  49.318167 -123.934833
# 2895           2895  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 2896           2896  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 3533           3533  2013.0    3.0   7.0  16.628056  49.316500 -123.945667
# ...             ...     ...    ...   ...        ...        ...         ...
# 3690046      111634     NaN    NaN   NaN        NaN  48.996181 -123.141334
# 3690047      111635     NaN    NaN   NaN        NaN  48.998321 -123.136821
# 3690048      111636     NaN    NaN   NaN        NaN  48.999988 -123.133275
# 3690049      111637     NaN    NaN   NaN        NaN  49.001393 -123.131266
# 3690050      111638     NaN    NaN   NaN        NaN  49.002806 -123.129870
#
#                 Z         SA        CT  ...  conservative temperature (oC)  \
# 0        0.892338  27.814801  6.753649  ...                            NaN
# 1353     0.991488  28.529872  6.944525  ...                            NaN
# 2895     0.297447  28.267852  7.220572  ...                            NaN
# 2896     0.892339  28.304597  7.247064  ...                            NaN
# 3533     0.495745  28.513321  7.378918  ...                            NaN
# ...           ...        ...       ...  ...                            ...
# 3690046       NaN        NaN       NaN  ...                      13.003132
# 3690047       NaN        NaN       NaN  ...                      12.459163
# 3690048       NaN        NaN       NaN  ...                      12.637519
# 3690049       NaN        NaN       NaN  ...                      12.715566
# 3690050       NaN        NaN       NaN  ...                      12.652591
#
#          index  chlorophyll (ug/l) turbidity (NTU)  \
# 0          NaN                 NaN             NaN
# 1353       NaN                 NaN             NaN
# 2895       NaN                 NaN             NaN
# 2896       NaN                 NaN             NaN
# 3533       NaN                 NaN             NaN
# ...        ...                 ...             ...
# 3690046    NaN            3.012429        3.447286
# 3690047    NaN            2.076429        2.933986
# 3690048    NaN            2.442214        3.003521
# 3690049    NaN            2.300571        3.312429
# 3690050    NaN            2.151111        3.317111
#
#          o2_concentration_corrected (ml/l)  oxygen (uM)  indf_ptrc_T  \
# 0                                      NaN          NaN          NaN
# 1353                                   NaN          NaN          NaN
# 2895                                   NaN          NaN          NaN
# 2896                                   NaN          NaN          NaN
# 3533                                   NaN          NaN          NaN
# ...                                    ...          ...          ...
# 3690046                           6.999927   312.623733        169.0
# 3690047                           6.060600   270.672434        169.0
# 3690048                           6.065907   270.909453        169.0
# 3690049                           6.892608   307.830754        169.0
# 3690050                           7.118375   317.913754        169.0
#
#          ih_ptrc_T  indf_grid_T  ih_grid_T
# 0              NaN          NaN        NaN
# 1353           NaN          NaN        NaN
# 2895           NaN          NaN        NaN
# 2896           NaN          NaN        NaN
# 3533           NaN          NaN        NaN
# ...            ...          ...        ...
# 3690046        3.0        169.0        3.0
# 3690047        3.0        169.0        3.0
# 3690048        3.0        169.0        3.0
# 3690049        3.0        169.0        3.0
# 3690050        3.0        169.0        3.0
#
# [1536802 rows x 53 columns]
# 0.11438670909010792
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1353           1353  2013.0    2.0  13.0  16.696111  49.318167 -123.934833
# 2895           2895  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 2896           2896  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 3533           3533  2013.0    3.0   7.0  16.628056  49.316500 -123.945667
# ...             ...     ...    ...   ...        ...        ...         ...
# 3690046      111634     NaN    NaN   NaN        NaN  48.996181 -123.141334
# 3690047      111635     NaN    NaN   NaN        NaN  48.998321 -123.136821
# 3690048      111636     NaN    NaN   NaN        NaN  48.999988 -123.133275
# 3690049      111637     NaN    NaN   NaN        NaN  49.001393 -123.131266
# 3690050      111638     NaN    NaN   NaN        NaN  49.002806 -123.129870
#
#                 Z         SA        CT  ...  chlorophyll (ug/l)  \
# 0        0.892338  27.814801  6.753649  ...                 NaN
# 1353     0.991488  28.529872  6.944525  ...                 NaN
# 2895     0.297447  28.267852  7.220572  ...                 NaN
# 2896     0.892339  28.304597  7.247064  ...                 NaN
# 3533     0.495745  28.513321  7.378918  ...                 NaN
# ...           ...        ...       ...  ...                 ...
# 3690046       NaN        NaN       NaN  ...            3.012429
# 3690047       NaN        NaN       NaN  ...            2.076429
# 3690048       NaN        NaN       NaN  ...            2.442214
# 3690049       NaN        NaN       NaN  ...            2.300571
# 3690050       NaN        NaN       NaN  ...            2.151111
#
#          turbidity (NTU)  o2_concentration_corrected (ml/l) oxygen (uM)  \
# 0                    NaN                                NaN         NaN
# 1353                 NaN                                NaN         NaN
# 2895                 NaN                                NaN         NaN
# 2896                 NaN                                NaN         NaN
# 3533                 NaN                                NaN         NaN
# ...                  ...                                ...         ...
# 3690046         3.447286                           6.999927  312.623733
# 3690047         2.933986                           6.060600  270.672434
# 3690048         3.003521                           6.065907  270.909453
# 3690049         3.312429                           6.892608  307.830754
# 3690050         3.317111                           7.118375  317.913754
#
#          indf_biol_T  ih_biol_T  indf_grid_T  ih_grid_T  indf_chem_T  \
# 0                NaN        NaN          NaN        NaN          NaN
# 1353             NaN        NaN          NaN        NaN          NaN
# 2895             NaN        NaN          NaN        NaN          NaN
# 2896             NaN        NaN          NaN        NaN          NaN
# 3533             NaN        NaN          NaN        NaN          NaN
# ...              ...        ...          ...        ...          ...
# 3690046        169.0        3.0        169.0        3.0        169.0
# 3690047        169.0        3.0        169.0        3.0        169.0
# 3690048        169.0        3.0        169.0        3.0        169.0
# 3690049        169.0        3.0        169.0        3.0        169.0
# 3690050        169.0        3.0        169.0        3.0        169.0
#
#          ih_chem_T
# 0              NaN
# 1353           NaN
# 2895           NaN
# 2896           NaN
# 3533           NaN
# ...            ...
# 3690046        3.0
# 3690047        3.0
# 3690048        3.0
# 3690049        3.0
# 3690050        3.0
#
# [1536806 rows x 55 columns]
# 0.08580151533774154
# /tmp/ipykernel_2628431/714136494.py:56: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(alltogether.to_latex(column_format='lcccccccccc',
# <style type="text/css">
# #T_d71fb_row0_col0, #T_d71fb_row0_col1, #T_d71fb_row0_col2, #T_d71fb_row0_col3, #T_d71fb_row0_col4, #T_d71fb_row0_col5, #T_d71fb_row0_col6, #T_d71fb_row0_col7, #T_d71fb_row0_col8, #T_d71fb_row0_col9 {
#   color: red;
# }
# #T_d71fb_row1_col0, #T_d71fb_row1_col1, #T_d71fb_row1_col2, #T_d71fb_row1_col3, #T_d71fb_row1_col4, #T_d71fb_row1_col5, #T_d71fb_row1_col6, #T_d71fb_row1_col7, #T_d71fb_row1_col8, #T_d71fb_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_d71fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d71fb_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_d71fb_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_d71fb_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_d71fb_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_d71fb_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_d71fb_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_d71fb_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_d71fb_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_d71fb_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_d71fb_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d71fb_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_d71fb_row0_col0" class="data row0 col0" >50438</td>
#       <td id="T_d71fb_row0_col1" class="data row0 col1" >-0.742</td>
#       <td id="T_d71fb_row0_col2" class="data row0 col2" >2.25</td>
#       <td id="T_d71fb_row0_col3" class="data row0 col3" >2.12</td>
#       <td id="T_d71fb_row0_col4" class="data row0 col4" >0.114</td>
#       <td id="T_d71fb_row0_col5" class="data row0 col5" >-0.176</td>
#       <td id="T_d71fb_row0_col6" class="data row0 col6" >-5.49</td>
#       <td id="T_d71fb_row0_col7" class="data row0 col7" >0.931</td>
#       <td id="T_d71fb_row0_col8" class="data row0 col8" >2.25</td>
#       <td id="T_d71fb_row0_col9" class="data row0 col9" >-2.63</td>
#     </tr>
#     <tr>
#       <th id="T_d71fb_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_d71fb_row1_col0" class="data row1 col0" >50393</td>
#       <td id="T_d71fb_row1_col1" class="data row1 col1" >-0.51</td>
#       <td id="T_d71fb_row1_col2" class="data row1 col2" >1.93</td>
#       <td id="T_d71fb_row1_col3" class="data row1 col3" >1.87</td>
#       <td id="T_d71fb_row1_col4" class="data row1 col4" >0.0858</td>
#       <td id="T_d71fb_row1_col5" class="data row1 col5" >-0.138</td>
#       <td id="T_d71fb_row1_col6" class="data row1 col6" >-4.24</td>
#       <td id="T_d71fb_row1_col7" class="data row1 col7" >0.675</td>
#       <td id="T_d71fb_row1_col8" class="data row1 col8" >1.95</td>
#       <td id="T_d71fb_row1_col9" class="data row1 col9" >-2.44</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Top 5m: CTD only

# %%
idepth = 0
jdepth = 5

results, counts1, counts2 = plot_allyears([2015, 2016, 2017], [2015, 2016, 2017], 
                                          [2015, 2016, 2017], 
                                          [],  
                                          [],
                                          idepth, jdepth, 'top5m', reverse=False)
results.style.format(myformat).apply(highlight_max_min)
# Out:
# 0 5
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2015.0    1.0   9.0  16.994444  49.328833 -124.080833
# 65               65  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 66               66  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 176             176  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 177             177  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# ...             ...     ...    ...   ...        ...        ...         ...
# 1059299       54226     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059300       54227     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059301       54228     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059302       54229     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059303       54230     NaN    NaN   NaN        NaN  47.356205 -123.024873
#
#                   Z         SA         CT  ...  o2SAT  o2uM  conductivity  \
# 0          0.991487  25.146111   6.992043  ...    NaN   NaN           NaN
# 65         0.396595  26.067362   7.390978  ...    NaN   NaN           NaN
# 66         0.793188  26.077290   7.388385  ...    NaN   NaN           NaN
# 176      109.926371  30.348049   9.911225  ...    NaN   NaN           NaN
# 177      110.917323  30.361132   9.912794  ...    NaN   NaN           NaN
# ...             ...        ...        ...  ...    ...   ...           ...
# 1059299   51.500000  30.519269  11.197092  ...    NaN   NaN           NaN
# 1059300   52.000000  30.519279  11.197434  ...    NaN   NaN           NaN
# 1059301   52.500000  30.519390  11.197373  ...    NaN   NaN           NaN
# 1059302   53.000000  30.519501  11.197412  ...    NaN   NaN           NaN
# 1059303   53.500000  30.519612  11.197450  ...    NaN   NaN           NaN
#
#         temperature  Station             Basin    Sigma       Chl  SiteCode  \
# 0               NaN      NaN               NaN      NaN       NaN       NaN
# 65              NaN      NaN               NaN      NaN       NaN       NaN
# 66              NaN      NaN               NaN      NaN       NaN       NaN
# 176             NaN      NaN               NaN      NaN       NaN       NaN
# 177             NaN      NaN               NaN      NaN       NaN       NaN
# ...             ...      ...               ...      ...       ...       ...
# 1059299         NaN   HCB004  Hood Canal Basin  23.1545  0.250486    HCB004
# 1059300         NaN   HCB004  Hood Canal Basin  23.1544  0.274727    HCB004
# 1059301         NaN   HCB004  Hood Canal Basin  23.1545  0.288194    HCB004
# 1059302         NaN   HCB004  Hood Canal Basin  23.1546  0.274727    HCB004
# 1059303         NaN   HCB004  Hood Canal Basin  23.1547  0.272033    HCB004
#
#          mod_dissolved_oxygen
# 0                         NaN
# 65                        NaN
# 66                        NaN
# 176                       NaN
# 177                       NaN
# ...                       ...
# 1059299                   NaN
# 1059300                   NaN
# 1059301                   NaN
# 1059302                   NaN
# 1059303                   NaN
#
# [25412 rows x 39 columns]
# 0.12284892131749534
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2015.0    1.0   9.0  16.994444  49.328833 -124.080833
# 65               65  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 66               66  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 176             176  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 177             177  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# ...             ...     ...    ...   ...        ...        ...         ...
# 1059299       54226     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059300       54227     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059301       54228     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059302       54229     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059303       54230     NaN    NaN   NaN        NaN  47.356205 -123.024873
#
#                   Z         SA         CT  ...  chl  o2SAT  o2uM conductivity  \
# 0          0.991487  25.146111   6.992043  ...  NaN    NaN   NaN          NaN
# 65         0.396595  26.067362   7.390978  ...  NaN    NaN   NaN          NaN
# 66         0.793188  26.077290   7.388385  ...  NaN    NaN   NaN          NaN
# 176      109.926371  30.348049   9.911225  ...  NaN    NaN   NaN          NaN
# 177      110.917323  30.361132   9.912794  ...  NaN    NaN   NaN          NaN
# ...             ...        ...        ...  ...  ...    ...   ...          ...
# 1059299   51.500000  30.519269  11.197092  ...  NaN    NaN   NaN          NaN
# 1059300   52.000000  30.519279  11.197434  ...  NaN    NaN   NaN          NaN
# 1059301   52.500000  30.519390  11.197373  ...  NaN    NaN   NaN          NaN
# 1059302   53.000000  30.519501  11.197412  ...  NaN    NaN   NaN          NaN
# 1059303   53.500000  30.519612  11.197450  ...  NaN    NaN   NaN          NaN
#
#          temperature  Station             Basin    Sigma       Chl  SiteCode
# 0                NaN      NaN               NaN      NaN       NaN       NaN
# 65               NaN      NaN               NaN      NaN       NaN       NaN
# 66               NaN      NaN               NaN      NaN       NaN       NaN
# 176              NaN      NaN               NaN      NaN       NaN       NaN
# 177              NaN      NaN               NaN      NaN       NaN       NaN
# ...              ...      ...               ...      ...       ...       ...
# 1059299          NaN   HCB004  Hood Canal Basin  23.1545  0.250486    HCB004
# 1059300          NaN   HCB004  Hood Canal Basin  23.1544  0.274727    HCB004
# 1059301          NaN   HCB004  Hood Canal Basin  23.1545  0.288194    HCB004
# 1059302          NaN   HCB004  Hood Canal Basin  23.1546  0.274727    HCB004
# 1059303          NaN   HCB004  Hood Canal Basin  23.1547  0.272033    HCB004
#
# [25401 rows x 39 columns]
# 0.08868027257672102
# /tmp/ipykernel_2628431/714136494.py:56: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(alltogether.to_latex(column_format='lcccccccccc',
# <style type="text/css">
# #T_13167_row0_col0, #T_13167_row0_col1, #T_13167_row0_col2, #T_13167_row0_col3, #T_13167_row0_col4, #T_13167_row0_col5, #T_13167_row0_col6, #T_13167_row0_col7, #T_13167_row0_col8, #T_13167_row0_col9 {
#   color: red;
# }
# #T_13167_row1_col0, #T_13167_row1_col1, #T_13167_row1_col2, #T_13167_row1_col3, #T_13167_row1_col4, #T_13167_row1_col5, #T_13167_row1_col6, #T_13167_row1_col7, #T_13167_row1_col8, #T_13167_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_13167">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13167_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_13167_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_13167_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_13167_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_13167_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_13167_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_13167_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_13167_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_13167_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_13167_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13167_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_13167_row0_col0" class="data row0 col0" >39458</td>
#       <td id="T_13167_row0_col1" class="data row0 col1" >-0.78</td>
#       <td id="T_13167_row0_col2" class="data row0 col2" >2.28</td>
#       <td id="T_13167_row0_col3" class="data row0 col3" >2.15</td>
#       <td id="T_13167_row0_col4" class="data row0 col4" >0.123</td>
#       <td id="T_13167_row0_col5" class="data row0 col5" >-0.213</td>
#       <td id="T_13167_row0_col6" class="data row0 col6" >-6.5</td>
#       <td id="T_13167_row0_col7" class="data row0 col7" >1.02</td>
#       <td id="T_13167_row0_col8" class="data row0 col8" >2.3</td>
#       <td id="T_13167_row0_col9" class="data row0 col9" >-0.369</td>
#     </tr>
#     <tr>
#       <th id="T_13167_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_13167_row1_col0" class="data row1 col0" >39431</td>
#       <td id="T_13167_row1_col1" class="data row1 col1" >-0.507</td>
#       <td id="T_13167_row1_col2" class="data row1 col2" >1.91</td>
#       <td id="T_13167_row1_col3" class="data row1 col3" >1.84</td>
#       <td id="T_13167_row1_col4" class="data row1 col4" >0.0887</td>
#       <td id="T_13167_row1_col5" class="data row1 col5" >-0.151</td>
#       <td id="T_13167_row1_col6" class="data row1 col6" >-4.56</td>
#       <td id="T_13167_row1_col7" class="data row1 col7" >0.69</td>
#       <td id="T_13167_row1_col8" class="data row1 col8" >1.93</td>
#       <td id="T_13167_row1_col9" class="data row1 col9" >-0.276</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Top 5m: 202905 (not rerun)

# %%
idepth = 0
jdepth = 5

results, counts1, counts2 = plot_allyears([2015, 2016, 2017], [2015, 2016, 2017], 
                                          [2015, 2016, 2017], 
                                          [],  
                                          [],
                                          idepth, jdepth, 'top5m')
results.style.format(myformat).apply(highlight_max_min)
# Out:
# 0 5
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2015.0    1.0   9.0  16.994444  49.328833 -124.080833
# 65               65  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 66               66  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 176             176  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 177             177  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# ...             ...     ...    ...   ...        ...        ...         ...
# 1059299       54226     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059300       54227     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059301       54228     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059302       54229     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059303       54230     NaN    NaN   NaN        NaN  47.356205 -123.024873
#
#                   Z         SA         CT  ...  o2SAT  o2uM  conductivity  \
# 0          0.991487  25.146111   6.992043  ...    NaN   NaN           NaN
# 65         0.396595  26.067362   7.390978  ...    NaN   NaN           NaN
# 66         0.793188  26.077290   7.388385  ...    NaN   NaN           NaN
# 176      109.926371  30.348049   9.911225  ...    NaN   NaN           NaN
# 177      110.917323  30.361132   9.912794  ...    NaN   NaN           NaN
# ...             ...        ...        ...  ...    ...   ...           ...
# 1059299   51.500000  30.519269  11.197092  ...    NaN   NaN           NaN
# 1059300   52.000000  30.519279  11.197434  ...    NaN   NaN           NaN
# 1059301   52.500000  30.519390  11.197373  ...    NaN   NaN           NaN
# 1059302   53.000000  30.519501  11.197412  ...    NaN   NaN           NaN
# 1059303   53.500000  30.519612  11.197450  ...    NaN   NaN           NaN
#
#         temperature  Station             Basin    Sigma       Chl  SiteCode  \
# 0               NaN      NaN               NaN      NaN       NaN       NaN
# 65              NaN      NaN               NaN      NaN       NaN       NaN
# 66              NaN      NaN               NaN      NaN       NaN       NaN
# 176             NaN      NaN               NaN      NaN       NaN       NaN
# 177             NaN      NaN               NaN      NaN       NaN       NaN
# ...             ...      ...               ...      ...       ...       ...
# 1059299         NaN   HCB004  Hood Canal Basin  23.1545  0.250486    HCB004
# 1059300         NaN   HCB004  Hood Canal Basin  23.1544  0.274727    HCB004
# 1059301         NaN   HCB004  Hood Canal Basin  23.1545  0.288194    HCB004
# 1059302         NaN   HCB004  Hood Canal Basin  23.1546  0.274727    HCB004
# 1059303         NaN   HCB004  Hood Canal Basin  23.1547  0.272033    HCB004
#
#          mod_dissolved_oxygen
# 0                         NaN
# 65                        NaN
# 66                        NaN
# 176                       NaN
# 177                       NaN
# ...                       ...
# 1059299                   NaN
# 1059300                   NaN
# 1059301                   NaN
# 1059302                   NaN
# 1059303                   NaN
#
# [25412 rows x 39 columns]
# 0.12284892131749534
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2015.0    1.0   9.0  16.994444  49.328833 -124.080833
# 65               65  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 66               66  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 176             176  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# 177             177  2015.0    1.0  14.0  19.052222  49.350667 -124.159167
# ...             ...     ...    ...   ...        ...        ...         ...
# 1059299       54226     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059300       54227     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059301       54228     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059302       54229     NaN    NaN   NaN        NaN  47.356205 -123.024873
# 1059303       54230     NaN    NaN   NaN        NaN  47.356205 -123.024873
#
#                   Z         SA         CT  ...  chl  o2SAT  o2uM conductivity  \
# 0          0.991487  25.146111   6.992043  ...  NaN    NaN   NaN          NaN
# 65         0.396595  26.067362   7.390978  ...  NaN    NaN   NaN          NaN
# 66         0.793188  26.077290   7.388385  ...  NaN    NaN   NaN          NaN
# 176      109.926371  30.348049   9.911225  ...  NaN    NaN   NaN          NaN
# 177      110.917323  30.361132   9.912794  ...  NaN    NaN   NaN          NaN
# ...             ...        ...        ...  ...  ...    ...   ...          ...
# 1059299   51.500000  30.519269  11.197092  ...  NaN    NaN   NaN          NaN
# 1059300   52.000000  30.519279  11.197434  ...  NaN    NaN   NaN          NaN
# 1059301   52.500000  30.519390  11.197373  ...  NaN    NaN   NaN          NaN
# 1059302   53.000000  30.519501  11.197412  ...  NaN    NaN   NaN          NaN
# 1059303   53.500000  30.519612  11.197450  ...  NaN    NaN   NaN          NaN
#
#          temperature  Station             Basin    Sigma       Chl  SiteCode
# 0                NaN      NaN               NaN      NaN       NaN       NaN
# 65               NaN      NaN               NaN      NaN       NaN       NaN
# 66               NaN      NaN               NaN      NaN       NaN       NaN
# 176              NaN      NaN               NaN      NaN       NaN       NaN
# 177              NaN      NaN               NaN      NaN       NaN       NaN
# ...              ...      ...               ...      ...       ...       ...
# 1059299          NaN   HCB004  Hood Canal Basin  23.1545  0.250486    HCB004
# 1059300          NaN   HCB004  Hood Canal Basin  23.1544  0.274727    HCB004
# 1059301          NaN   HCB004  Hood Canal Basin  23.1545  0.288194    HCB004
# 1059302          NaN   HCB004  Hood Canal Basin  23.1546  0.274727    HCB004
# 1059303          NaN   HCB004  Hood Canal Basin  23.1547  0.272033    HCB004
#
# [25401 rows x 39 columns]
# 0.08868027257672102
# /tmp/ipykernel_2628431/714136494.py:56: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(alltogether.to_latex(column_format='lcccccccccc',
# <style type="text/css">
# #T_7441f_row0_col0, #T_7441f_row0_col1, #T_7441f_row0_col2, #T_7441f_row0_col3, #T_7441f_row0_col4, #T_7441f_row0_col5, #T_7441f_row0_col6, #T_7441f_row0_col7, #T_7441f_row0_col8, #T_7441f_row0_col9 {
#   color: red;
# }
# #T_7441f_row1_col0, #T_7441f_row1_col1, #T_7441f_row1_col2, #T_7441f_row1_col3, #T_7441f_row1_col4, #T_7441f_row1_col5, #T_7441f_row1_col6, #T_7441f_row1_col7, #T_7441f_row1_col8, #T_7441f_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_7441f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7441f_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_7441f_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_7441f_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_7441f_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_7441f_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_7441f_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_7441f_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_7441f_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_7441f_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_7441f_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7441f_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_7441f_row0_col0" class="data row0 col0" >39458</td>
#       <td id="T_7441f_row0_col1" class="data row0 col1" >-0.78</td>
#       <td id="T_7441f_row0_col2" class="data row0 col2" >2.28</td>
#       <td id="T_7441f_row0_col3" class="data row0 col3" >2.15</td>
#       <td id="T_7441f_row0_col4" class="data row0 col4" >0.123</td>
#       <td id="T_7441f_row0_col5" class="data row0 col5" >-0.213</td>
#       <td id="T_7441f_row0_col6" class="data row0 col6" >-6.5</td>
#       <td id="T_7441f_row0_col7" class="data row0 col7" >1.02</td>
#       <td id="T_7441f_row0_col8" class="data row0 col8" >2.3</td>
#       <td id="T_7441f_row0_col9" class="data row0 col9" >-0.369</td>
#     </tr>
#     <tr>
#       <th id="T_7441f_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_7441f_row1_col0" class="data row1 col0" >39431</td>
#       <td id="T_7441f_row1_col1" class="data row1 col1" >-0.507</td>
#       <td id="T_7441f_row1_col2" class="data row1 col2" >1.91</td>
#       <td id="T_7441f_row1_col3" class="data row1 col3" >1.84</td>
#       <td id="T_7441f_row1_col4" class="data row1 col4" >0.0887</td>
#       <td id="T_7441f_row1_col5" class="data row1 col5" >-0.151</td>
#       <td id="T_7441f_row1_col6" class="data row1 col6" >-4.56</td>
#       <td id="T_7441f_row1_col7" class="data row1 col7" >0.69</td>
#       <td id="T_7441f_row1_col8" class="data row1 col8" >1.93</td>
#       <td id="T_7441f_row1_col9" class="data row1 col9" >-0.276</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Below 5 m

# %%
idepth = 5
jdepth = 39

results, counts1, counts2 = plot_allyears([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], 
                                          [2015, 2016, 2017], [2015, 2016, 2017, 2018], 
                                          [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022], 
                                          [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
                                          idepth, jdepth, 'below5m')
results.style.format(myformat).apply(highlight_max_min)
# Out:
# 5 39
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1                 1  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 2                 2  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 3                 3  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 4                 4  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# ...             ...     ...    ...   ...        ...        ...         ...
# 3690046      111634     NaN    NaN   NaN        NaN  48.996181 -123.141334
# 3690047      111635     NaN    NaN   NaN        NaN  48.998321 -123.136821
# 3690048      111636     NaN    NaN   NaN        NaN  48.999988 -123.133275
# 3690049      111637     NaN    NaN   NaN        NaN  49.001393 -123.131266
# 3690050      111638     NaN    NaN   NaN        NaN  49.002806 -123.129870
#
#                 Z         SA        CT  ...  conservative temperature (oC)  \
# 0        0.892338  27.814801  6.753649  ...                            NaN
# 1        1.883821  27.826002  6.762110  ...                            NaN
# 2        2.974446  27.842222  6.764341  ...                            NaN
# 3        4.065065  27.901148  6.812357  ...                            NaN
# 4        4.957386  28.036150  6.874438  ...                            NaN
# ...           ...        ...       ...  ...                            ...
# 3690046       NaN        NaN       NaN  ...                      13.003132
# 3690047       NaN        NaN       NaN  ...                      12.459163
# 3690048       NaN        NaN       NaN  ...                      12.637519
# 3690049       NaN        NaN       NaN  ...                      12.715566
# 3690050       NaN        NaN       NaN  ...                      12.652591
#
#          index  chlorophyll (ug/l) turbidity (NTU)  \
# 0          NaN                 NaN             NaN
# 1          NaN                 NaN             NaN
# 2          NaN                 NaN             NaN
# 3          NaN                 NaN             NaN
# 4          NaN                 NaN             NaN
# ...        ...                 ...             ...
# 3690046    NaN            3.012429        3.447286
# 3690047    NaN            2.076429        2.933986
# 3690048    NaN            2.442214        3.003521
# 3690049    NaN            2.300571        3.312429
# 3690050    NaN            2.151111        3.317111
#
#          o2_concentration_corrected (ml/l)  oxygen (uM)  indf_ptrc_T  \
# 0                                      NaN          NaN          NaN
# 1                                      NaN          NaN          NaN
# 2                                      NaN          NaN          NaN
# 3                                      NaN          NaN          NaN
# 4                                      NaN          NaN          NaN
# ...                                    ...          ...          ...
# 3690046                           6.999927   312.623733        169.0
# 3690047                           6.060600   270.672434        169.0
# 3690048                           6.065907   270.909453        169.0
# 3690049                           6.892608   307.830754        169.0
# 3690050                           7.118375   317.913754        169.0
#
#          ih_ptrc_T  indf_grid_T  ih_grid_T
# 0              NaN          NaN        NaN
# 1              NaN          NaN        NaN
# 2              NaN          NaN        NaN
# 3              NaN          NaN        NaN
# 4              NaN          NaN        NaN
# ...            ...          ...        ...
# 3690046        3.0        169.0        3.0
# 3690047        3.0        169.0        3.0
# 3690048        3.0        169.0        3.0
# 3690049        3.0        169.0        3.0
# 3690050        3.0        169.0        3.0
#
# [1592882 rows x 53 columns]
# 0.03192946139596788
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1                 1  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 2                 2  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 3                 3  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 4                 4  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# ...             ...     ...    ...   ...        ...        ...         ...
# 3690046      111634     NaN    NaN   NaN        NaN  48.996181 -123.141334
# 3690047      111635     NaN    NaN   NaN        NaN  48.998321 -123.136821
# 3690048      111636     NaN    NaN   NaN        NaN  48.999988 -123.133275
# 3690049      111637     NaN    NaN   NaN        NaN  49.001393 -123.131266
# 3690050      111638     NaN    NaN   NaN        NaN  49.002806 -123.129870
#
#                 Z         SA        CT  ...  chlorophyll (ug/l)  \
# 0        0.892338  27.814801  6.753649  ...                 NaN
# 1        1.883821  27.826002  6.762110  ...                 NaN
# 2        2.974446  27.842222  6.764341  ...                 NaN
# 3        4.065065  27.901148  6.812357  ...                 NaN
# 4        4.957386  28.036150  6.874438  ...                 NaN
# ...           ...        ...       ...  ...                 ...
# 3690046       NaN        NaN       NaN  ...            3.012429
# 3690047       NaN        NaN       NaN  ...            2.076429
# 3690048       NaN        NaN       NaN  ...            2.442214
# 3690049       NaN        NaN       NaN  ...            2.300571
# 3690050       NaN        NaN       NaN  ...            2.151111
#
#          turbidity (NTU)  o2_concentration_corrected (ml/l) oxygen (uM)  \
# 0                    NaN                                NaN         NaN
# 1                    NaN                                NaN         NaN
# 2                    NaN                                NaN         NaN
# 3                    NaN                                NaN         NaN
# 4                    NaN                                NaN         NaN
# ...                  ...                                ...         ...
# 3690046         3.447286                           6.999927  312.623733
# 3690047         2.933986                           6.060600  270.672434
# 3690048         3.003521                           6.065907  270.909453
# 3690049         3.312429                           6.892608  307.830754
# 3690050         3.317111                           7.118375  317.913754
#
#          indf_biol_T  ih_biol_T  indf_grid_T  ih_grid_T  indf_chem_T  \
# 0                NaN        NaN          NaN        NaN          NaN
# 1                NaN        NaN          NaN        NaN          NaN
# 2                NaN        NaN          NaN        NaN          NaN
# 3                NaN        NaN          NaN        NaN          NaN
# 4                NaN        NaN          NaN        NaN          NaN
# ...              ...        ...          ...        ...          ...
# 3690046        169.0        3.0        169.0        3.0        169.0
# 3690047        169.0        3.0        169.0        3.0        169.0
# 3690048        169.0        3.0        169.0        3.0        169.0
# 3690049        169.0        3.0        169.0        3.0        169.0
# 3690050        169.0        3.0        169.0        3.0        169.0
#
#          ih_chem_T
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 3690046        3.0
# 3690047        3.0
# 3690048        3.0
# 3690049        3.0
# 3690050        3.0
#
# [1592868 rows x 55 columns]
# 0.02702463453876469
# /tmp/ipykernel_2628431/714136494.py:56: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(alltogether.to_latex(column_format='lcccccccccc',
# <style type="text/css">
# #T_9e623_row0_col0, #T_9e623_row0_col5, #T_9e623_row0_col6, #T_9e623_row0_col9, #T_9e623_row1_col1, #T_9e623_row1_col2, #T_9e623_row1_col3, #T_9e623_row1_col4, #T_9e623_row1_col7, #T_9e623_row1_col8 {
#   color: darkgreen;
# }
# #T_9e623_row0_col1, #T_9e623_row0_col2, #T_9e623_row0_col3, #T_9e623_row0_col4, #T_9e623_row0_col7, #T_9e623_row0_col8, #T_9e623_row1_col0, #T_9e623_row1_col5, #T_9e623_row1_col6, #T_9e623_row1_col9 {
#   color: red;
# }
# </style>
# <table id="T_9e623">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e623_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_9e623_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_9e623_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_9e623_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_9e623_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_9e623_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_9e623_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_9e623_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_9e623_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_9e623_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e623_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_9e623_row0_col0" class="data row0 col0" >1495871</td>
#       <td id="T_9e623_row0_col1" class="data row0 col1" >0.0666</td>
#       <td id="T_9e623_row0_col2" class="data row0 col2" >0.401</td>
#       <td id="T_9e623_row0_col3" class="data row0 col3" >0.395</td>
#       <td id="T_9e623_row0_col4" class="data row0 col4" >0.0319</td>
#       <td id="T_9e623_row0_col5" class="data row0 col5" >0.0125</td>
#       <td id="T_9e623_row0_col6" class="data row0 col6" >0.446</td>
#       <td id="T_9e623_row0_col7" class="data row0 col7" >0.0681</td>
#       <td id="T_9e623_row0_col8" class="data row0 col8" >0.392</td>
#       <td id="T_9e623_row0_col9" class="data row0 col9" >0.205</td>
#     </tr>
#     <tr>
#       <th id="T_9e623_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_9e623_row1_col0" class="data row1 col0" >1495885</td>
#       <td id="T_9e623_row1_col1" class="data row1 col1" >0.0355</td>
#       <td id="T_9e623_row1_col2" class="data row1 col2" >0.366</td>
#       <td id="T_9e623_row1_col3" class="data row1 col3" >0.364</td>
#       <td id="T_9e623_row1_col4" class="data row1 col4" >0.027</td>
#       <td id="T_9e623_row1_col5" class="data row1 col5" >0.0293</td>
#       <td id="T_9e623_row1_col6" class="data row1 col6" >0.922</td>
#       <td id="T_9e623_row1_col7" class="data row1 col7" >0.0488</td>
#       <td id="T_9e623_row1_col8" class="data row1 col8" >0.358</td>
#       <td id="T_9e623_row1_col9" class="data row1 col9" >0.236</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Regionals

# %%
def stats_only(temp1, name, idepth, jdepth, corn, boxname):
    select = temp1[(temp1.k >= idepth) & (temp1.k <= jdepth) &
                              (temp1.j >= corn[0]) & (temp1.j <= corn[1]) &
                              (temp1.i >= corn[2]) & (temp1.i <= corn[3])]
    number, tbias = bias(select, obsn, modn)
    if number > 0:
        trmse = rmse(select, obsn, modn)
        tcrmse = crmse(trmse, tbias)
        tswillmott = swillmott(select, obsn, modn)
        a1, b1, syst, nonsyst = wolfram_perp(select, obsn, modn)
        tspread = spread(select, obsn, modn)
        Cp2 = {'number': number,
            'bias': tbias,
          'rmse': trmse,
          'crmse': tcrmse,
          'swillmott': tswillmott,
          'slopedev': 1-b1,
          'const': a1,
          'systematic': syst,
          'nonsystematic': nonsyst,
          'spread': tspread,
          'region': boxname}
        dCp2 = pd.DataFrame(data=Cp2, index=[name])
    else:
        dCp2 = 0
    return number, dCp2

# %%
def stats_allregions(years, years_psf, years_pug, years_onc, years_ferry, idepth, jdepth, whichdepths):
    pieces1 = []
    for year in years:
        pieces1.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ctd_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_psfts_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_pugts_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_onc_{year}0101_{year}1231.csv')    
    for year in years_ferry:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ferry_{year}0101_{year}1231.csv')    
    temp1 = read_pieces(pieces1)
    
    number, alltogether = stats_only(filter_bad_data(temp1), '201905R', idepth, jdepth, boxes[0], boxnames[0])
    for boxname, corn in zip(boxnames[1:], boxes[1:]):
        number, d201905 = stats_only(filter_bad_data(temp1), '201905R', idepth, jdepth, corn, boxname)
        if number > 0:
            alltogether = pd.concat([alltogether, d201905], axis=0)

    pieces2 = []
    for year in years:
        pieces2.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ctd_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_psfts_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_pugts_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ferry_{year}0101_{year}1231.csv')
    temp2 = read_pieces(pieces2)
   
    for boxname, corn in zip(boxnames, boxes):
        number, d202111 = stats_only(filter_bad_data(temp2), '202111', idepth, jdepth, corn, boxname)
        if number > 0:
            alltogether = pd.concat([alltogether, d202111], axis=0)
    f = open(f'./{whichdepths}_{field}_201905_202111_for_allregions_table.tex', 'w')
    f.write(alltogether.to_latex(column_format='lccccccccccl', 
            formatters=[None, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, None]))
    f.close()
    return alltogether

# %%
def stats_and_plot(years, years_psf, years_pug, years_onc, years_ferry, idepth, jdepth, box, boxname, whichdepths):
    fig, axs = plt.subplots(1, 4, figsize=(20, 4))
    fig.suptitle(f'{boxname} Year {years[0]}-{years[-1]}')
    
    pieces1 = []
    for year in years:
        pieces1.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ctd_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_psfts_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_pugts_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_onc_{year}0101_{year}1231.csv')   
    for year in years_ferry:
        pieces1.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_ferry_{year}0101_{year}1231.csv')   
    temp1 = read_pieces(pieces1)
    
    alltogether, counts = plot_and_stats(filter_bad_data(temp1), '201905R', idepth, jdepth, fig, axs[0], whichdepths, False, '', boxes=True, box=box, boxname=boxname)

    pieces2 = []
    for year in years:
        pieces2.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ctd_{year}0101_{year}1231.csv'
             )
    for year in years_psf:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_psfts_{year}0101_{year}1231.csv')
    for year in years_pug:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_pugts_{year}0101_{year}1231.csv')
    for year in years_onc:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_onc_{year}0101_{year}1231.csv')
    for year in years_ferry:
        pieces2.append(
            f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_ferry_{year}0101_{year}1231.csv')
    temp2 = read_pieces(pieces2)
    d202111, counts = plot_and_stats(filter_bad_data(temp2), '202111', idepth, jdepth, fig, axs[1], whichdepths, False, '', boxes=True, box=box, boxname=boxname)
    
    plot_profiles(temp1, temp2, axs[2], axs[3], box, boxname)
    
    
    alltogether = pd.concat([alltogether, d202111], axis=0)

# %%
def plot_profiles(temp1, temp2, ax, ax2, box, boxname):

    corn = box
    temp1['diff'] = temp1[modn] - temp1[obsn]
    select = temp1[(temp1.k >= idepth) & (temp1.k <= jdepth) &
                              (temp1.j >= corn[0]) & (temp1.j <= corn[1]) &
                              (temp1.i >= corn[2]) & (temp1.i <= corn[3])]
    kls = len(select.groupby('k')[obsn])
    ax.plot(select.groupby('k')[obsn].mean(), deptht[:kls], 'o-', c='tab:green', label='Observations')
    ax.plot(select.groupby('k')[modn].mean(), deptht[:kls], 'o-', c='tab:blue', label='201905')
    ax2.plot(select.groupby('k')['diff'].mean(), deptht[:kls], '-', c='tab:blue', label='201905')
    ax.fill_betweenx(deptht[:kls], select[['k', modn]].groupby('k').quantile(q=0.25)[modn], select[['k', modn]].groupby('k').quantile(q=0.75)[modn], alpha=0.2, color='tab:blue')
    ax2.fill_betweenx(deptht[:kls], select[['k', 'diff']].groupby('k').quantile(q=0.25)['diff'], select[['k', 'diff']].groupby('k').quantile(q=0.75)['diff'], alpha=0.2, color='tab:blue')
    
    temp2['diff'] = temp2[modn] - temp2[obsn]
    select = temp2[(temp2.k >= idepth) & (temp2.k <= jdepth) &
                              (temp2.j >= corn[0]) & (temp2.j <= corn[1]) &
                              (temp2.i >= corn[2]) & (temp2.i <= corn[3])]
    
    ax.plot(select.groupby('k')[modn].mean(), deptht[:kls], 'o-', c='tab:orange', label='202111')
    ax2.plot(select.groupby('k')['diff'].mean(), deptht[:kls], '-', c='tab:orange', label='202111')
    ax.fill_betweenx(deptht[:kls], select[['k', modn]].groupby('k').quantile(q=0.25)[modn], select[['k', modn]].groupby('k').quantile(q=0.75)[modn], alpha=0.2, color='tab:orange')
    ax.fill_betweenx(deptht[:kls], select[['k', obsn]].groupby('k').quantile(q=0.25)[obsn], select[['k', obsn]].groupby('k').quantile(q=0.75)[obsn], alpha=0.2, color='tab:orange')
    ax2.fill_betweenx(deptht[:kls], select[['k', 'diff']].groupby('k').quantile(q=0.25)['diff'], select[['k', 'diff']].groupby('k').quantile(q=0.75)['diff'], alpha=0.2, color='tab:orange')
    
    ax.invert_yaxis()
    ax2.invert_yaxis()
    
    ax.legend()
    ax2.legend()
    ax.set_title(f'{field} Profiles')
    ax2.set_title(f'{field} Difference Profiles')
    ax2.grid();

# %%
def plot_box(ax, corn, colour):
    ax.plot([corn[2], corn[3], corn[3], corn[2], corn[2]], 
            [corn[0], corn[0], corn[1], corn[1], corn[0]], '-', color=colour)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 9))
mycmap = cm.deep
mycmap.set_bad('grey')
ax.pcolormesh(bathy['Bathymetry'], cmap=mycmap)
viz_tools.set_aspect(ax);
SoG_center = [450, 550, 200, 300]
plot_box(ax, SoG_center, 'b')
SoG_north = [650, 730, 100, 200]
plot_box(ax, SoG_north, 'g')
SoG_south = [320, 380, 280, 350]
plot_box(ax, SoG_south, 'k')
Haro_Boundary = [290, 350, 210, 280]
plot_box(ax, Haro_Boundary, 'g')
JdF_east = [200, 290, 150, 260]
plot_box(ax, JdF_east, 'b')
JdF_west = [250, 425, 25, 125]
plot_box(ax, JdF_west, 'k')
PS_main = [20, 150, 200, 280]
plot_box(ax, PS_main, 'k')
SS_all = [0, 898, 0, 398]
boxes = [SS_all, SoG_south,SoG_center, SoG_north, PS_main, Haro_Boundary, JdF_west, JdF_east]
boxnames = ['SS_all', 'SoG_south', 'SoG_center', 'SoG_north', 'PS_main', 'Haro_Boundary',
           'JdF_west', 'JdF_east']
Fraser_plume = [380, 460, 260, 330]
plot_box(ax, Fraser_plume, 'm')

# %% [markdown]
# ## All Depths

# %%
idepth = 0
jdepth = 39

results = stats_allregions([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], [2015, 2016, 2017], [2015, 2016, 2017, 2018], [2015, 2016, 2017, 2018, 2019, 2020, 2021], 
                           [2015, 2016, 2017, 2018, 2019],
                           idepth, jdepth, 'alldepths')
for boxname in boxnames:
    if results[results.region == boxname].number[0] > 0:
        print(f'\033[1m{boxname}\033[1m')
        display(results[results.region == boxname].loc[:, results.columns != 'region'].style.format(myformat).apply(highlight_max_min))
# Out:
# SS_all
# /tmp/ipykernel_2628431/2185682482.py:51: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(alltogether.to_latex(column_format='lccccccccccl',
# <style type="text/css">
# #T_93ba2_row0_col0, #T_93ba2_row0_col1, #T_93ba2_row0_col2, #T_93ba2_row0_col3, #T_93ba2_row0_col4, #T_93ba2_row0_col5, #T_93ba2_row0_col6, #T_93ba2_row0_col7, #T_93ba2_row0_col8, #T_93ba2_row0_col9 {
#   color: red;
# }
# #T_93ba2_row1_col0, #T_93ba2_row1_col1, #T_93ba2_row1_col2, #T_93ba2_row1_col3, #T_93ba2_row1_col4, #T_93ba2_row1_col5, #T_93ba2_row1_col6, #T_93ba2_row1_col7, #T_93ba2_row1_col8, #T_93ba2_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_93ba2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93ba2_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_93ba2_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_93ba2_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_93ba2_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_93ba2_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_93ba2_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_93ba2_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_93ba2_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_93ba2_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_93ba2_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93ba2_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_93ba2_row0_col0" class="data row0 col0" >1546309</td>
#       <td id="T_93ba2_row0_col1" class="data row0 col1" >0.0402</td>
#       <td id="T_93ba2_row0_col2" class="data row0 col2" >0.566</td>
#       <td id="T_93ba2_row0_col3" class="data row0 col3" >0.564</td>
#       <td id="T_93ba2_row0_col4" class="data row0 col4" >0.0403</td>
#       <td id="T_93ba2_row0_col5" class="data row0 col5" >-0.0702</td>
#       <td id="T_93ba2_row0_col6" class="data row0 col6" >-2.08</td>
#       <td id="T_93ba2_row0_col7" class="data row0 col7" >0.106</td>
#       <td id="T_93ba2_row0_col8" class="data row0 col8" >0.576</td>
#       <td id="T_93ba2_row0_col9" class="data row0 col9" >-11.5</td>
#     </tr>
#     <tr>
#       <th id="T_93ba2_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_93ba2_row1_col0" class="data row1 col0" >1546278</td>
#       <td id="T_93ba2_row1_col1" class="data row1 col1" >0.0177</td>
#       <td id="T_93ba2_row1_col2" class="data row1 col2" >0.502</td>
#       <td id="T_93ba2_row1_col3" class="data row1 col3" >0.501</td>
#       <td id="T_93ba2_row1_col4" class="data row1 col4" >0.0324</td>
#       <td id="T_93ba2_row1_col5" class="data row1 col5" >-0.0366</td>
#       <td id="T_93ba2_row1_col6" class="data row1 col6" >-1.09</td>
#       <td id="T_93ba2_row1_col7" class="data row1 col7" >0.0539</td>
#       <td id="T_93ba2_row1_col8" class="data row1 col8" >0.508</td>
#       <td id="T_93ba2_row1_col9" class="data row1 col9" >-10.3</td>
#     </tr>
#   </tbody>
# </table>
# SoG_south
# <style type="text/css">
# #T_96872_row0_col0, #T_96872_row0_col1, #T_96872_row0_col2, #T_96872_row0_col3, #T_96872_row0_col4, #T_96872_row0_col5, #T_96872_row0_col6, #T_96872_row0_col7, #T_96872_row0_col8, #T_96872_row0_col9, #T_96872_row1_col0 {
#   color: red;
# }
# #T_96872_row1_col1, #T_96872_row1_col2, #T_96872_row1_col3, #T_96872_row1_col4, #T_96872_row1_col5, #T_96872_row1_col6, #T_96872_row1_col7, #T_96872_row1_col8, #T_96872_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_96872">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96872_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_96872_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_96872_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_96872_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_96872_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_96872_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_96872_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_96872_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_96872_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_96872_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96872_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_96872_row0_col0" class="data row0 col0" >46591</td>
#       <td id="T_96872_row0_col1" class="data row0 col1" >0.0905</td>
#       <td id="T_96872_row0_col2" class="data row0 col2" >0.494</td>
#       <td id="T_96872_row0_col3" class="data row0 col3" >0.486</td>
#       <td id="T_96872_row0_col4" class="data row0 col4" >0.052</td>
#       <td id="T_96872_row0_col5" class="data row0 col5" >-0.0281</td>
#       <td id="T_96872_row0_col6" class="data row0 col6" >-0.758</td>
#       <td id="T_96872_row0_col7" class="data row0 col7" >0.0956</td>
#       <td id="T_96872_row0_col8" class="data row0 col8" >0.492</td>
#       <td id="T_96872_row0_col9" class="data row0 col9" >-0.0542</td>
#     </tr>
#     <tr>
#       <th id="T_96872_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_96872_row1_col0" class="data row1 col0" >46591</td>
#       <td id="T_96872_row1_col1" class="data row1 col1" >0.0594</td>
#       <td id="T_96872_row1_col2" class="data row1 col2" >0.466</td>
#       <td id="T_96872_row1_col3" class="data row1 col3" >0.462</td>
#       <td id="T_96872_row1_col4" class="data row1 col4" >0.0481</td>
#       <td id="T_96872_row1_col5" class="data row1 col5" >0.0188</td>
#       <td id="T_96872_row1_col6" class="data row1 col6" >0.628</td>
#       <td id="T_96872_row1_col7" class="data row1 col7" >0.0629</td>
#       <td id="T_96872_row1_col8" class="data row1 col8" >0.457</td>
#       <td id="T_96872_row1_col9" class="data row1 col9" >0.0317</td>
#     </tr>
#   </tbody>
# </table>
# SoG_center
# <style type="text/css">
# #T_eeb4f_row0_col0, #T_eeb4f_row0_col1, #T_eeb4f_row0_col2, #T_eeb4f_row0_col3, #T_eeb4f_row0_col4, #T_eeb4f_row0_col5, #T_eeb4f_row0_col6, #T_eeb4f_row0_col7, #T_eeb4f_row0_col8, #T_eeb4f_row0_col9, #T_eeb4f_row1_col0 {
#   color: red;
# }
# #T_eeb4f_row1_col1, #T_eeb4f_row1_col2, #T_eeb4f_row1_col3, #T_eeb4f_row1_col4, #T_eeb4f_row1_col5, #T_eeb4f_row1_col6, #T_eeb4f_row1_col7, #T_eeb4f_row1_col8, #T_eeb4f_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_eeb4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eeb4f_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_eeb4f_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_eeb4f_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_eeb4f_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_eeb4f_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_eeb4f_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_eeb4f_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_eeb4f_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_eeb4f_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_eeb4f_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeb4f_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_eeb4f_row0_col0" class="data row0 col0" >335946</td>
#       <td id="T_eeb4f_row0_col1" class="data row0 col1" >0.119</td>
#       <td id="T_eeb4f_row0_col2" class="data row0 col2" >0.48</td>
#       <td id="T_eeb4f_row0_col3" class="data row0 col3" >0.465</td>
#       <td id="T_eeb4f_row0_col4" class="data row0 col4" >0.036</td>
#       <td id="T_eeb4f_row0_col5" class="data row0 col5" >-0.109</td>
#       <td id="T_eeb4f_row0_col6" class="data row0 col6" >-3.21</td>
#       <td id="T_eeb4f_row0_col7" class="data row0 col7" >0.179</td>
#       <td id="T_eeb4f_row0_col8" class="data row0 col8" >0.472</td>
#       <td id="T_eeb4f_row0_col9" class="data row0 col9" >-12.3</td>
#     </tr>
#     <tr>
#       <th id="T_eeb4f_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_eeb4f_row1_col0" class="data row1 col0" >335946</td>
#       <td id="T_eeb4f_row1_col1" class="data row1 col1" >0.0664</td>
#       <td id="T_eeb4f_row1_col2" class="data row1 col2" >0.421</td>
#       <td id="T_eeb4f_row1_col3" class="data row1 col3" >0.416</td>
#       <td id="T_eeb4f_row1_col4" class="data row1 col4" >0.0289</td>
#       <td id="T_eeb4f_row1_col5" class="data row1 col5" >-0.0583</td>
#       <td id="T_eeb4f_row1_col6" class="data row1 col6" >-1.71</td>
#       <td id="T_eeb4f_row1_col7" class="data row1 col7" >0.0973</td>
#       <td id="T_eeb4f_row1_col8" class="data row1 col8" >0.422</td>
#       <td id="T_eeb4f_row1_col9" class="data row1 col9" >-11.7</td>
#     </tr>
#   </tbody>
# </table>
# SoG_north
# <style type="text/css">
# #T_fc98d_row0_col0, #T_fc98d_row0_col5, #T_fc98d_row0_col6, #T_fc98d_row0_col9, #T_fc98d_row1_col1, #T_fc98d_row1_col2, #T_fc98d_row1_col3, #T_fc98d_row1_col4, #T_fc98d_row1_col7, #T_fc98d_row1_col8 {
#   color: darkgreen;
# }
# #T_fc98d_row0_col1, #T_fc98d_row0_col2, #T_fc98d_row0_col3, #T_fc98d_row0_col4, #T_fc98d_row0_col7, #T_fc98d_row0_col8, #T_fc98d_row1_col0, #T_fc98d_row1_col5, #T_fc98d_row1_col6, #T_fc98d_row1_col9 {
#   color: red;
# }
# </style>
# <table id="T_fc98d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc98d_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_fc98d_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_fc98d_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_fc98d_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_fc98d_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_fc98d_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_fc98d_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_fc98d_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_fc98d_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_fc98d_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc98d_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_fc98d_row0_col0" class="data row0 col0" >220535</td>
#       <td id="T_fc98d_row0_col1" class="data row0 col1" >0.184</td>
#       <td id="T_fc98d_row0_col2" class="data row0 col2" >0.447</td>
#       <td id="T_fc98d_row0_col3" class="data row0 col3" >0.407</td>
#       <td id="T_fc98d_row0_col4" class="data row0 col4" >0.0449</td>
#       <td id="T_fc98d_row0_col5" class="data row0 col5" >-0.0354</td>
#       <td id="T_fc98d_row0_col6" class="data row0 col6" >-0.865</td>
#       <td id="T_fc98d_row0_col7" class="data row0 col7" >0.188</td>
#       <td id="T_fc98d_row0_col8" class="data row0 col8" >0.413</td>
#       <td id="T_fc98d_row0_col9" class="data row0 col9" >-0.0683</td>
#     </tr>
#     <tr>
#       <th id="T_fc98d_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_fc98d_row1_col0" class="data row1 col0" >220542</td>
#       <td id="T_fc98d_row1_col1" class="data row1 col1" >0.153</td>
#       <td id="T_fc98d_row1_col2" class="data row1 col2" >0.401</td>
#       <td id="T_fc98d_row1_col3" class="data row1 col3" >0.371</td>
#       <td id="T_fc98d_row1_col4" class="data row1 col4" >0.039</td>
#       <td id="T_fc98d_row1_col5" class="data row1 col5" >0.0471</td>
#       <td id="T_fc98d_row1_col6" class="data row1 col6" >1.55</td>
#       <td id="T_fc98d_row1_col7" class="data row1 col7" >0.161</td>
#       <td id="T_fc98d_row1_col8" class="data row1 col8" >0.359</td>
#       <td id="T_fc98d_row1_col9" class="data row1 col9" >0.0842</td>
#     </tr>
#   </tbody>
# </table>
# PS_main
# <style type="text/css">
# #T_f02c9_row0_col0, #T_f02c9_row0_col2, #T_f02c9_row0_col3, #T_f02c9_row0_col4, #T_f02c9_row1_col0, #T_f02c9_row1_col1, #T_f02c9_row1_col5, #T_f02c9_row1_col6, #T_f02c9_row1_col7, #T_f02c9_row1_col8, #T_f02c9_row1_col9 {
#   color: red;
# }
# #T_f02c9_row0_col1, #T_f02c9_row0_col5, #T_f02c9_row0_col6, #T_f02c9_row0_col7, #T_f02c9_row0_col8, #T_f02c9_row0_col9, #T_f02c9_row1_col2, #T_f02c9_row1_col3, #T_f02c9_row1_col4 {
#   color: darkgreen;
# }
# </style>
# <table id="T_f02c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f02c9_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_f02c9_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_f02c9_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_f02c9_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_f02c9_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_f02c9_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_f02c9_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_f02c9_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_f02c9_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_f02c9_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f02c9_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_f02c9_row0_col0" class="data row0 col0" >48823</td>
#       <td id="T_f02c9_row0_col1" class="data row0 col1" >0.105</td>
#       <td id="T_f02c9_row0_col2" class="data row0 col2" >0.541</td>
#       <td id="T_f02c9_row0_col3" class="data row0 col3" >0.531</td>
#       <td id="T_f02c9_row0_col4" class="data row0 col4" >0.134</td>
#       <td id="T_f02c9_row0_col5" class="data row0 col5" >-0.00371</td>
#       <td id="T_f02c9_row0_col6" class="data row0 col6" >-0.00568</td>
#       <td id="T_f02c9_row0_col7" class="data row0 col7" >0.105</td>
#       <td id="T_f02c9_row0_col8" class="data row0 col8" >0.532</td>
#       <td id="T_f02c9_row0_col9" class="data row0 col9" >-0.00824</td>
#     </tr>
#     <tr>
#       <th id="T_f02c9_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_f02c9_row1_col0" class="data row1 col0" >48823</td>
#       <td id="T_f02c9_row1_col1" class="data row1 col1" >0.155</td>
#       <td id="T_f02c9_row1_col2" class="data row1 col2" >0.533</td>
#       <td id="T_f02c9_row1_col3" class="data row1 col3" >0.51</td>
#       <td id="T_f02c9_row1_col4" class="data row1 col4" >0.104</td>
#       <td id="T_f02c9_row1_col5" class="data row1 col5" >-0.248</td>
#       <td id="T_f02c9_row1_col6" class="data row1 col6" >-7.23</td>
#       <td id="T_f02c9_row1_col7" class="data row1 col7" >0.246</td>
#       <td id="T_f02c9_row1_col8" class="data row1 col8" >0.543</td>
#       <td id="T_f02c9_row1_col9" class="data row1 col9" >-0.451</td>
#     </tr>
#   </tbody>
# </table>
# Haro_Boundary
# <style type="text/css">
# #T_0943e_row0_col0, #T_0943e_row0_col2, #T_0943e_row0_col3, #T_0943e_row0_col4, #T_0943e_row0_col5, #T_0943e_row0_col6, #T_0943e_row0_col8, #T_0943e_row0_col9, #T_0943e_row1_col0, #T_0943e_row1_col1, #T_0943e_row1_col7 {
#   color: red;
# }
# #T_0943e_row0_col1, #T_0943e_row0_col7, #T_0943e_row1_col2, #T_0943e_row1_col3, #T_0943e_row1_col4, #T_0943e_row1_col5, #T_0943e_row1_col6, #T_0943e_row1_col8, #T_0943e_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_0943e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0943e_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_0943e_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_0943e_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_0943e_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_0943e_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_0943e_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_0943e_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_0943e_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_0943e_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_0943e_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0943e_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_0943e_row0_col0" class="data row0 col0" >42328</td>
#       <td id="T_0943e_row0_col1" class="data row0 col1" >-0.0655</td>
#       <td id="T_0943e_row0_col2" class="data row0 col2" >0.375</td>
#       <td id="T_0943e_row0_col3" class="data row0 col3" >0.369</td>
#       <td id="T_0943e_row0_col4" class="data row0 col4" >0.0471</td>
#       <td id="T_0943e_row0_col5" class="data row0 col5" >-0.0673</td>
#       <td id="T_0943e_row0_col6" class="data row0 col6" >-2.17</td>
#       <td id="T_0943e_row0_col7" class="data row0 col7" >0.0871</td>
#       <td id="T_0943e_row0_col8" class="data row0 col8" >0.377</td>
#       <td id="T_0943e_row0_col9" class="data row0 col9" >-0.127</td>
#     </tr>
#     <tr>
#       <th id="T_0943e_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_0943e_row1_col0" class="data row1 col0" >42328</td>
#       <td id="T_0943e_row1_col1" class="data row1 col1" >-0.0896</td>
#       <td id="T_0943e_row1_col2" class="data row1 col2" >0.348</td>
#       <td id="T_0943e_row1_col3" class="data row1 col3" >0.336</td>
#       <td id="T_0943e_row1_col4" class="data row1 col4" >0.0407</td>
#       <td id="T_0943e_row1_col5" class="data row1 col5" >-0.0581</td>
#       <td id="T_0943e_row1_col6" class="data row1 col6" >-1.91</td>
#       <td id="T_0943e_row1_col7" class="data row1 col7" >0.102</td>
#       <td id="T_0943e_row1_col8" class="data row1 col8" >0.343</td>
#       <td id="T_0943e_row1_col9" class="data row1 col9" >-0.111</td>
#     </tr>
#   </tbody>
# </table>
# JdF_west
# <style type="text/css">
# #T_795ad_row0_col0, #T_795ad_row0_col2, #T_795ad_row0_col3, #T_795ad_row0_col4, #T_795ad_row0_col8, #T_795ad_row1_col0, #T_795ad_row1_col1, #T_795ad_row1_col5, #T_795ad_row1_col6, #T_795ad_row1_col7, #T_795ad_row1_col9 {
#   color: red;
# }
# #T_795ad_row0_col1, #T_795ad_row0_col5, #T_795ad_row0_col6, #T_795ad_row0_col7, #T_795ad_row0_col9, #T_795ad_row1_col2, #T_795ad_row1_col3, #T_795ad_row1_col4, #T_795ad_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_795ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_795ad_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_795ad_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_795ad_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_795ad_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_795ad_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_795ad_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_795ad_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_795ad_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_795ad_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_795ad_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_795ad_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_795ad_row0_col0" class="data row0 col0" >25283</td>
#       <td id="T_795ad_row0_col1" class="data row0 col1" >-0.0871</td>
#       <td id="T_795ad_row0_col2" class="data row0 col2" >0.413</td>
#       <td id="T_795ad_row0_col3" class="data row0 col3" >0.403</td>
#       <td id="T_795ad_row0_col4" class="data row0 col4" >0.0366</td>
#       <td id="T_795ad_row0_col5" class="data row0 col5" >-0.0153</td>
#       <td id="T_795ad_row0_col6" class="data row0 col6" >-0.59</td>
#       <td id="T_795ad_row0_col7" class="data row0 col7" >0.0886</td>
#       <td id="T_795ad_row0_col8" class="data row0 col8" >0.406</td>
#       <td id="T_795ad_row0_col9" class="data row0 col9" >-0.0275</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_795ad_row1_col0" class="data row1 col0" >25283</td>
#       <td id="T_795ad_row1_col1" class="data row1 col1" >-0.0898</td>
#       <td id="T_795ad_row1_col2" class="data row1 col2" >0.391</td>
#       <td id="T_795ad_row1_col3" class="data row1 col3" >0.38</td>
#       <td id="T_795ad_row1_col4" class="data row1 col4" >0.0326</td>
#       <td id="T_795ad_row1_col5" class="data row1 col5" >-0.0207</td>
#       <td id="T_795ad_row1_col6" class="data row1 col6" >-0.769</td>
#       <td id="T_795ad_row1_col7" class="data row1 col7" >0.0926</td>
#       <td id="T_795ad_row1_col8" class="data row1 col8" >0.384</td>
#       <td id="T_795ad_row1_col9" class="data row1 col9" >-0.0372</td>
#     </tr>
#   </tbody>
# </table>
# JdF_east
# <style type="text/css">
# #T_21c70_row0_col0, #T_21c70_row0_col2, #T_21c70_row0_col3, #T_21c70_row0_col4, #T_21c70_row0_col8, #T_21c70_row1_col0, #T_21c70_row1_col1, #T_21c70_row1_col5, #T_21c70_row1_col6, #T_21c70_row1_col7, #T_21c70_row1_col9 {
#   color: red;
# }
# #T_21c70_row0_col1, #T_21c70_row0_col5, #T_21c70_row0_col6, #T_21c70_row0_col7, #T_21c70_row0_col9, #T_21c70_row1_col2, #T_21c70_row1_col3, #T_21c70_row1_col4, #T_21c70_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_21c70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21c70_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_21c70_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_21c70_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_21c70_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_21c70_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_21c70_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_21c70_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_21c70_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_21c70_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_21c70_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21c70_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_21c70_row0_col0" class="data row0 col0" >65390</td>
#       <td id="T_21c70_row0_col1" class="data row0 col1" >-0.0877</td>
#       <td id="T_21c70_row0_col2" class="data row0 col2" >0.405</td>
#       <td id="T_21c70_row0_col3" class="data row0 col3" >0.396</td>
#       <td id="T_21c70_row0_col4" class="data row0 col4" >0.0516</td>
#       <td id="T_21c70_row0_col5" class="data row0 col5" >-0.0022</td>
#       <td id="T_21c70_row0_col6" class="data row0 col6" >-0.158</td>
#       <td id="T_21c70_row0_col7" class="data row0 col7" >0.0877</td>
#       <td id="T_21c70_row0_col8" class="data row0 col8" >0.396</td>
#       <td id="T_21c70_row0_col9" class="data row0 col9" >-0.00603</td>
#     </tr>
#     <tr>
#       <th id="T_21c70_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_21c70_row1_col0" class="data row1 col0" >65390</td>
#       <td id="T_21c70_row1_col1" class="data row1 col1" >-0.109</td>
#       <td id="T_21c70_row1_col2" class="data row1 col2" >0.373</td>
#       <td id="T_21c70_row1_col3" class="data row1 col3" >0.356</td>
#       <td id="T_21c70_row1_col4" class="data row1 col4" >0.0424</td>
#       <td id="T_21c70_row1_col5" class="data row1 col5" >-0.0256</td>
#       <td id="T_21c70_row1_col6" class="data row1 col6" >-0.921</td>
#       <td id="T_21c70_row1_col7" class="data row1 col7" >0.111</td>
#       <td id="T_21c70_row1_col8" class="data row1 col8" >0.36</td>
#       <td id="T_21c70_row1_col9" class="data row1 col9" >-0.0498</td>
#     </tr>
#   </tbody>
# </table>

# %%
stats_and_plot([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], [2015, 2016, 2017], [2015, 2016, 2017, 2018], [2015, 2016, 2017, 2018, 2019, 2020], 
               [2015, 2016, 2017, 2018, 2019],
               idepth, jdepth, SoG_south, 'SoG_south', 'alldepths')
# Out:
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1353           1353  2013.0    2.0  13.0  16.696111  49.318167 -123.934833
# 2895           2895  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 2896           2896  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 3533           3533  2013.0    3.0   7.0  16.628056  49.316500 -123.945667
# ...             ...     ...    ...   ...        ...        ...         ...
# 2802459      171184     NaN    NaN   NaN        NaN  49.171881 -123.630172
# 2802460      171185     NaN    NaN   NaN        NaN  49.174657 -123.637464
# 2802461      171186     NaN    NaN   NaN        NaN  49.177499 -123.644701
# 2802462      171187     NaN    NaN   NaN        NaN  49.180270 -123.652008
# 2802463      171188     NaN    NaN   NaN        NaN  49.183008 -123.659329
#
#                 Z         SA        CT  ...  conservative temperature (oC)  \
# 0        0.892338  27.814801  6.753649  ...                            NaN
# 1353     0.991488  28.529872  6.944525  ...                            NaN
# 2895     0.297447  28.267852  7.220572  ...                            NaN
# 2896     0.892339  28.304597  7.247064  ...                            NaN
# 3533     0.495745  28.513321  7.378918  ...                            NaN
# ...           ...        ...       ...  ...                            ...
# 2802459       NaN        NaN       NaN  ...                      12.126162
# 2802460       NaN        NaN       NaN  ...                      12.150364
# 2802461       NaN        NaN       NaN  ...                      12.169626
# 2802462       NaN        NaN       NaN  ...                      12.147157
# 2802463       NaN        NaN       NaN  ...                      12.162530
#
#          index  chlorophyll (ug/l) turbidity (NTU)  \
# 0          NaN                 NaN             NaN
# 1353       NaN                 NaN             NaN
# 2895       NaN                 NaN             NaN
# 2896       NaN                 NaN             NaN
# 3533       NaN                 NaN             NaN
# ...        ...                 ...             ...
# 2802459    NaN            1.619357        4.383700
# 2802460    NaN            1.611000        4.370214
# 2802461    NaN            1.571571        4.360521
# 2802462    NaN            1.575857        4.417414
# 2802463    NaN            1.594909        4.441520
#
#          o2_concentration_corrected (ml/l)  oxygen (uM)  indf_ptrc_T  \
# 0                                      NaN          NaN          NaN
# 1353                                   NaN          NaN          NaN
# 2895                                   NaN          NaN          NaN
# 2896                                   NaN          NaN          NaN
# 3533                                   NaN          NaN          NaN
# ...                                    ...          ...          ...
# 2802459                           6.415552   286.524975        287.0
# 2802460                           6.391331   285.443224        287.0
# 2802461                           6.362735   284.166118        287.0
# 2802462                           6.321704   282.333631        287.0
# 2802463                           6.293091   281.055758        287.0
#
#          ih_ptrc_T  indf_grid_T  ih_grid_T
# 0              NaN          NaN        NaN
# 1353           NaN          NaN        NaN
# 2895           NaN          NaN        NaN
# 2896           NaN          NaN        NaN
# 3533           NaN          NaN        NaN
# ...            ...          ...        ...
# 2802459       23.0        287.0       23.0
# 2802460       23.0        287.0       23.0
# 2802461       23.0        287.0       23.0
# 2802462       23.0        287.0       23.0
# 2802463       23.0        287.0       23.0
#
# [761573 rows x 53 columns]
# 0.051955738148698076
#          Unnamed: 0    Year  Month   Day       Hour        Lat         Lon  \
# 0                 0  2013.0    1.0  10.0  17.118056  49.329667 -124.081000
# 1353           1353  2013.0    2.0  13.0  16.696111  49.318167 -123.934833
# 2895           2895  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 2896           2896  2013.0    3.0   5.0  16.368611  49.325667 -123.952000
# 3533           3533  2013.0    3.0   7.0  16.628056  49.316500 -123.945667
# ...             ...     ...    ...   ...        ...        ...         ...
# 2802459      171184     NaN    NaN   NaN        NaN  49.171881 -123.630172
# 2802460      171185     NaN    NaN   NaN        NaN  49.174657 -123.637464
# 2802461      171186     NaN    NaN   NaN        NaN  49.177499 -123.644701
# 2802462      171187     NaN    NaN   NaN        NaN  49.180270 -123.652008
# 2802463      171188     NaN    NaN   NaN        NaN  49.183008 -123.659329
#
#                 Z         SA        CT  ...  chlorophyll (ug/l)  \
# 0        0.892338  27.814801  6.753649  ...                 NaN
# 1353     0.991488  28.529872  6.944525  ...                 NaN
# 2895     0.297447  28.267852  7.220572  ...                 NaN
# 2896     0.892339  28.304597  7.247064  ...                 NaN
# 3533     0.495745  28.513321  7.378918  ...                 NaN
# ...           ...        ...       ...  ...                 ...
# 2802459       NaN        NaN       NaN  ...            1.619357
# 2802460       NaN        NaN       NaN  ...            1.611000
# 2802461       NaN        NaN       NaN  ...            1.571571
# 2802462       NaN        NaN       NaN  ...            1.575857
# 2802463       NaN        NaN       NaN  ...            1.594909
#
#          turbidity (NTU)  o2_concentration_corrected (ml/l) oxygen (uM)  \
# 0                    NaN                                NaN         NaN
# 1353                 NaN                                NaN         NaN
# 2895                 NaN                                NaN         NaN
# 2896                 NaN                                NaN         NaN
# 3533                 NaN                                NaN         NaN
# ...                  ...                                ...         ...
# 2802459         4.383700                           6.415552  286.524975
# 2802460         4.370214                           6.391331  285.443224
# 2802461         4.360521                           6.362735  284.166118
# 2802462         4.417414                           6.321704  282.333631
# 2802463         4.441520                           6.293091  281.055758
#
#          indf_biol_T  ih_biol_T  indf_grid_T  ih_grid_T  indf_chem_T  \
# 0                NaN        NaN          NaN        NaN          NaN
# 1353             NaN        NaN          NaN        NaN          NaN
# 2895             NaN        NaN          NaN        NaN          NaN
# 2896             NaN        NaN          NaN        NaN          NaN
# 3533             NaN        NaN          NaN        NaN          NaN
# ...              ...        ...          ...        ...          ...
# 2802459        287.0       23.0        287.0       23.0        287.0
# 2802460        287.0       23.0        287.0       23.0        287.0
# 2802461        287.0       23.0        287.0       23.0        287.0
# 2802462        287.0       23.0        287.0       23.0        287.0
# 2802463        287.0       23.0        287.0       23.0        287.0
#
#          ih_chem_T
# 0              NaN
# 1353           NaN
# 2895           NaN
# 2896           NaN
# 3533           NaN
# ...            ...
# 2802459       23.0
# 2802460       23.0
# 2802461       23.0
# 2802462       23.0
# 2802463       23.0
#
# [761577 rows x 55 columns]
# 0.04814706779792155

# %% [markdown]
# ## Above 5 m

# %%
idepth = 0
jdepth = 5

results = stats_allregions([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], [2015, 2016, 2017], [2015, 2016, 2017, 2018], [2015, 2016, 2017, 2018, 2019, 2020, 2021], 
                           [2015, 2016, 2017, 2018, 2019], 
                           idepth, jdepth, 'top5m')
for boxname in boxnames:
    if results[results.region == boxname].number[0] > 0:
        print(f'\033[1m{boxname}\033[1m')
        display(results[results.region == boxname].loc[:, results.columns != 'region'].style.format(myformat).apply(highlight_max_min))
# Out:
# SS_all
# /tmp/ipykernel_2628431/2185682482.py:51: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(alltogether.to_latex(column_format='lccccccccccl',
# <style type="text/css">
# #T_ed5b5_row0_col0, #T_ed5b5_row0_col1, #T_ed5b5_row0_col2, #T_ed5b5_row0_col3, #T_ed5b5_row0_col4, #T_ed5b5_row0_col5, #T_ed5b5_row0_col6, #T_ed5b5_row0_col7, #T_ed5b5_row0_col8, #T_ed5b5_row0_col9 {
#   color: red;
# }
# #T_ed5b5_row1_col0, #T_ed5b5_row1_col1, #T_ed5b5_row1_col2, #T_ed5b5_row1_col3, #T_ed5b5_row1_col4, #T_ed5b5_row1_col5, #T_ed5b5_row1_col6, #T_ed5b5_row1_col7, #T_ed5b5_row1_col8, #T_ed5b5_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_ed5b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed5b5_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_ed5b5_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_ed5b5_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_ed5b5_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_ed5b5_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_ed5b5_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_ed5b5_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_ed5b5_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_ed5b5_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_ed5b5_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed5b5_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_ed5b5_row0_col0" class="data row0 col0" >62019</td>
#       <td id="T_ed5b5_row0_col1" class="data row0 col1" >-0.64</td>
#       <td id="T_ed5b5_row0_col2" class="data row0 col2" >2.11</td>
#       <td id="T_ed5b5_row0_col3" class="data row0 col3" >2.01</td>
#       <td id="T_ed5b5_row0_col4" class="data row0 col4" >0.112</td>
#       <td id="T_ed5b5_row0_col5" class="data row0 col5" >-0.163</td>
#       <td id="T_ed5b5_row0_col6" class="data row0 col6" >-5.07</td>
#       <td id="T_ed5b5_row0_col7" class="data row0 col7" >0.811</td>
#       <td id="T_ed5b5_row0_col8" class="data row0 col8" >2.12</td>
#       <td id="T_ed5b5_row0_col9" class="data row0 col9" >-2.71</td>
#     </tr>
#     <tr>
#       <th id="T_ed5b5_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_ed5b5_row1_col0" class="data row1 col0" >61974</td>
#       <td id="T_ed5b5_row1_col1" class="data row1 col1" >-0.425</td>
#       <td id="T_ed5b5_row1_col2" class="data row1 col2" >1.83</td>
#       <td id="T_ed5b5_row1_col3" class="data row1 col3" >1.78</td>
#       <td id="T_ed5b5_row1_col4" class="data row1 col4" >0.0857</td>
#       <td id="T_ed5b5_row1_col5" class="data row1 col5" >-0.125</td>
#       <td id="T_ed5b5_row1_col6" class="data row1 col6" >-3.83</td>
#       <td id="T_ed5b5_row1_col7" class="data row1 col7" >0.572</td>
#       <td id="T_ed5b5_row1_col8" class="data row1 col8" >1.86</td>
#       <td id="T_ed5b5_row1_col9" class="data row1 col9" >-2.46</td>
#     </tr>
#   </tbody>
# </table>
# SoG_south
# <style type="text/css">
# #T_9c6cc_row0_col0, #T_9c6cc_row0_col2, #T_9c6cc_row0_col3, #T_9c6cc_row0_col8, #T_9c6cc_row1_col0, #T_9c6cc_row1_col1, #T_9c6cc_row1_col4, #T_9c6cc_row1_col5, #T_9c6cc_row1_col6, #T_9c6cc_row1_col7, #T_9c6cc_row1_col9 {
#   color: red;
# }
# #T_9c6cc_row0_col1, #T_9c6cc_row0_col4, #T_9c6cc_row0_col5, #T_9c6cc_row0_col6, #T_9c6cc_row0_col7, #T_9c6cc_row0_col9, #T_9c6cc_row1_col2, #T_9c6cc_row1_col3, #T_9c6cc_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_9c6cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c6cc_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_9c6cc_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_9c6cc_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_9c6cc_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_9c6cc_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_9c6cc_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_9c6cc_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_9c6cc_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_9c6cc_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_9c6cc_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c6cc_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_9c6cc_row0_col0" class="data row0 col0" >1431</td>
#       <td id="T_9c6cc_row0_col1" class="data row0 col1" >0.0187</td>
#       <td id="T_9c6cc_row0_col2" class="data row0 col2" >1.93</td>
#       <td id="T_9c6cc_row0_col3" class="data row0 col3" >1.93</td>
#       <td id="T_9c6cc_row0_col4" class="data row0 col4" >0.11</td>
#       <td id="T_9c6cc_row0_col5" class="data row0 col5" >0.026</td>
#       <td id="T_9c6cc_row0_col6" class="data row0 col6" >0.722</td>
#       <td id="T_9c6cc_row0_col7" class="data row0 col7" >0.0818</td>
#       <td id="T_9c6cc_row0_col8" class="data row0 col8" >1.9</td>
#       <td id="T_9c6cc_row0_col9" class="data row0 col9" >0.0513</td>
#     </tr>
#     <tr>
#       <th id="T_9c6cc_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_9c6cc_row1_col0" class="data row1 col0" >1431</td>
#       <td id="T_9c6cc_row1_col1" class="data row1 col1" >0.139</td>
#       <td id="T_9c6cc_row1_col2" class="data row1 col2" >1.86</td>
#       <td id="T_9c6cc_row1_col3" class="data row1 col3" >1.86</td>
#       <td id="T_9c6cc_row1_col4" class="data row1 col4" >0.11</td>
#       <td id="T_9c6cc_row1_col5" class="data row1 col5" >0.119</td>
#       <td id="T_9c6cc_row1_col6" class="data row1 col6" >3.36</td>
#       <td id="T_9c6cc_row1_col7" class="data row1 col7" >0.39</td>
#       <td id="T_9c6cc_row1_col8" class="data row1 col8" >1.72</td>
#       <td id="T_9c6cc_row1_col9" class="data row1 col9" >0.193</td>
#     </tr>
#   </tbody>
# </table>
# SoG_center
# <style type="text/css">
# #T_91111_row0_col0, #T_91111_row0_col1, #T_91111_row0_col2, #T_91111_row0_col3, #T_91111_row0_col4, #T_91111_row0_col5, #T_91111_row0_col6, #T_91111_row0_col7, #T_91111_row0_col8, #T_91111_row1_col0, #T_91111_row1_col9 {
#   color: red;
# }
# #T_91111_row0_col9, #T_91111_row1_col1, #T_91111_row1_col2, #T_91111_row1_col3, #T_91111_row1_col4, #T_91111_row1_col5, #T_91111_row1_col6, #T_91111_row1_col7, #T_91111_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_91111">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91111_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_91111_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_91111_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_91111_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_91111_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_91111_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_91111_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_91111_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_91111_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_91111_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91111_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_91111_row0_col0" class="data row0 col0" >6708</td>
#       <td id="T_91111_row0_col1" class="data row0 col1" >-1.15</td>
#       <td id="T_91111_row0_col2" class="data row0 col2" >2.7</td>
#       <td id="T_91111_row0_col3" class="data row0 col3" >2.45</td>
#       <td id="T_91111_row0_col4" class="data row0 col4" >0.137</td>
#       <td id="T_91111_row0_col5" class="data row0 col5" >-0.214</td>
#       <td id="T_91111_row0_col6" class="data row0 col6" >-6.62</td>
#       <td id="T_91111_row0_col7" class="data row0 col7" >1.37</td>
#       <td id="T_91111_row0_col8" class="data row0 col8" >2.62</td>
#       <td id="T_91111_row0_col9" class="data row0 col9" >-0.322</td>
#     </tr>
#     <tr>
#       <th id="T_91111_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_91111_row1_col0" class="data row1 col0" >6708</td>
#       <td id="T_91111_row1_col1" class="data row1 col1" >-0.789</td>
#       <td id="T_91111_row1_col2" class="data row1 col2" >2.4</td>
#       <td id="T_91111_row1_col3" class="data row1 col3" >2.27</td>
#       <td id="T_91111_row1_col4" class="data row1 col4" >0.108</td>
#       <td id="T_91111_row1_col5" class="data row1 col5" >-0.211</td>
#       <td id="T_91111_row1_col6" class="data row1 col6" >-6.16</td>
#       <td id="T_91111_row1_col7" class="data row1 col7" >1.07</td>
#       <td id="T_91111_row1_col8" class="data row1 col8" >2.41</td>
#       <td id="T_91111_row1_col9" class="data row1 col9" >-0.43</td>
#     </tr>
#   </tbody>
# </table>
# SoG_north
# <style type="text/css">
# #T_de9bf_row0_col0, #T_de9bf_row0_col1, #T_de9bf_row0_col2, #T_de9bf_row0_col3, #T_de9bf_row0_col4, #T_de9bf_row0_col5, #T_de9bf_row0_col6, #T_de9bf_row0_col7, #T_de9bf_row0_col8, #T_de9bf_row0_col9, #T_de9bf_row1_col0 {
#   color: red;
# }
# #T_de9bf_row1_col1, #T_de9bf_row1_col2, #T_de9bf_row1_col3, #T_de9bf_row1_col4, #T_de9bf_row1_col5, #T_de9bf_row1_col6, #T_de9bf_row1_col7, #T_de9bf_row1_col8, #T_de9bf_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_de9bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de9bf_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_de9bf_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_de9bf_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_de9bf_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_de9bf_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_de9bf_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_de9bf_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_de9bf_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_de9bf_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_de9bf_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de9bf_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_de9bf_row0_col0" class="data row0 col0" >10129</td>
#       <td id="T_de9bf_row0_col1" class="data row0 col1" >-0.26</td>
#       <td id="T_de9bf_row0_col2" class="data row0 col2" >1.38</td>
#       <td id="T_de9bf_row0_col3" class="data row0 col3" >1.36</td>
#       <td id="T_de9bf_row0_col4" class="data row0 col4" >0.15</td>
#       <td id="T_de9bf_row0_col5" class="data row0 col5" >-0.485</td>
#       <td id="T_de9bf_row0_col6" class="data row0 col6" >-13.4</td>
#       <td id="T_de9bf_row0_col7" class="data row0 col7" >0.806</td>
#       <td id="T_de9bf_row0_col8" class="data row0 col8" >1.51</td>
#       <td id="T_de9bf_row0_col9" class="data row0 col9" >-0.861</td>
#     </tr>
#     <tr>
#       <th id="T_de9bf_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_de9bf_row1_col0" class="data row1 col0" >10129</td>
#       <td id="T_de9bf_row1_col1" class="data row1 col1" >0.0956</td>
#       <td id="T_de9bf_row1_col2" class="data row1 col2" >1.19</td>
#       <td id="T_de9bf_row1_col3" class="data row1 col3" >1.19</td>
#       <td id="T_de9bf_row1_col4" class="data row1 col4" >0.127</td>
#       <td id="T_de9bf_row1_col5" class="data row1 col5" >-0.29</td>
#       <td id="T_de9bf_row1_col6" class="data row1 col6" >-7.74</td>
#       <td id="T_de9bf_row1_col7" class="data row1 col7" >0.465</td>
#       <td id="T_de9bf_row1_col8" class="data row1 col8" >1.3</td>
#       <td id="T_de9bf_row1_col9" class="data row1 col9" >-0.502</td>
#     </tr>
#   </tbody>
# </table>
# PS_main
# <style type="text/css">
# #T_fd2d8_row0_col0, #T_fd2d8_row0_col4, #T_fd2d8_row0_col8, #T_fd2d8_row1_col0, #T_fd2d8_row1_col1, #T_fd2d8_row1_col2, #T_fd2d8_row1_col3, #T_fd2d8_row1_col5, #T_fd2d8_row1_col6, #T_fd2d8_row1_col7, #T_fd2d8_row1_col9 {
#   color: red;
# }
# #T_fd2d8_row0_col1, #T_fd2d8_row0_col2, #T_fd2d8_row0_col3, #T_fd2d8_row0_col5, #T_fd2d8_row0_col6, #T_fd2d8_row0_col7, #T_fd2d8_row0_col9, #T_fd2d8_row1_col4, #T_fd2d8_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_fd2d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd2d8_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_fd2d8_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_fd2d8_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_fd2d8_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_fd2d8_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_fd2d8_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_fd2d8_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_fd2d8_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_fd2d8_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_fd2d8_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd2d8_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_fd2d8_row0_col0" class="data row0 col0" >1975</td>
#       <td id="T_fd2d8_row0_col1" class="data row0 col1" >-0.867</td>
#       <td id="T_fd2d8_row0_col2" class="data row0 col2" >1.58</td>
#       <td id="T_fd2d8_row0_col3" class="data row0 col3" >1.32</td>
#       <td id="T_fd2d8_row0_col4" class="data row0 col4" >0.304</td>
#       <td id="T_fd2d8_row0_col5" class="data row0 col5" >-0.137</td>
#       <td id="T_fd2d8_row0_col6" class="data row0 col6" >-4.79</td>
#       <td id="T_fd2d8_row0_col7" class="data row0 col7" >0.888</td>
#       <td id="T_fd2d8_row0_col8" class="data row0 col8" >1.41</td>
#       <td id="T_fd2d8_row0_col9" class="data row0 col9" >-0.168</td>
#     </tr>
#     <tr>
#       <th id="T_fd2d8_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_fd2d8_row1_col0" class="data row1 col0" >1975</td>
#       <td id="T_fd2d8_row1_col1" class="data row1 col1" >-1.17</td>
#       <td id="T_fd2d8_row1_col2" class="data row1 col2" >1.77</td>
#       <td id="T_fd2d8_row1_col3" class="data row1 col3" >1.33</td>
#       <td id="T_fd2d8_row1_col4" class="data row1 col4" >0.231</td>
#       <td id="T_fd2d8_row1_col5" class="data row1 col5" >-0.728</td>
#       <td id="T_fd2d8_row1_col6" class="data row1 col6" >-22.1</td>
#       <td id="T_fd2d8_row1_col7" class="data row1 col7" >1.55</td>
#       <td id="T_fd2d8_row1_col8" class="data row1 col8" >1.4</td>
#       <td id="T_fd2d8_row1_col9" class="data row1 col9" >-1.48</td>
#     </tr>
#   </tbody>
# </table>
# Haro_Boundary
# <style type="text/css">
# #T_ecc48_row0_col0, #T_ecc48_row0_col1, #T_ecc48_row0_col2, #T_ecc48_row0_col3, #T_ecc48_row0_col4, #T_ecc48_row0_col7, #T_ecc48_row0_col8, #T_ecc48_row1_col0, #T_ecc48_row1_col5, #T_ecc48_row1_col6, #T_ecc48_row1_col9 {
#   color: red;
# }
# #T_ecc48_row0_col5, #T_ecc48_row0_col6, #T_ecc48_row0_col9, #T_ecc48_row1_col1, #T_ecc48_row1_col2, #T_ecc48_row1_col3, #T_ecc48_row1_col4, #T_ecc48_row1_col7, #T_ecc48_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_ecc48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecc48_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_ecc48_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_ecc48_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_ecc48_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_ecc48_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_ecc48_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_ecc48_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_ecc48_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_ecc48_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_ecc48_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecc48_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_ecc48_row0_col0" class="data row0 col0" >1013</td>
#       <td id="T_ecc48_row0_col1" class="data row0 col1" >-0.619</td>
#       <td id="T_ecc48_row0_col2" class="data row0 col2" >0.969</td>
#       <td id="T_ecc48_row0_col3" class="data row0 col3" >0.745</td>
#       <td id="T_ecc48_row0_col4" class="data row0 col4" >0.196</td>
#       <td id="T_ecc48_row0_col5" class="data row0 col5" >-0.125</td>
#       <td id="T_ecc48_row0_col6" class="data row0 col6" >-4.37</td>
#       <td id="T_ecc48_row0_col7" class="data row0 col7" >0.632</td>
#       <td id="T_ecc48_row0_col8" class="data row0 col8" >0.784</td>
#       <td id="T_ecc48_row0_col9" class="data row0 col9" >-0.199</td>
#     </tr>
#     <tr>
#       <th id="T_ecc48_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_ecc48_row1_col0" class="data row1 col0" >1013</td>
#       <td id="T_ecc48_row1_col1" class="data row1 col1" >-0.575</td>
#       <td id="T_ecc48_row1_col2" class="data row1 col2" >0.879</td>
#       <td id="T_ecc48_row1_col3" class="data row1 col3" >0.666</td>
#       <td id="T_ecc48_row1_col4" class="data row1 col4" >0.161</td>
#       <td id="T_ecc48_row1_col5" class="data row1 col5" >-0.127</td>
#       <td id="T_ecc48_row1_col6" class="data row1 col6" >-4.4</td>
#       <td id="T_ecc48_row1_col7" class="data row1 col7" >0.59</td>
#       <td id="T_ecc48_row1_col8" class="data row1 col8" >0.698</td>
#       <td id="T_ecc48_row1_col9" class="data row1 col9" >-0.218</td>
#     </tr>
#   </tbody>
# </table>
# JdF_west
# <style type="text/css">
# #T_d73b9_row0_col0, #T_d73b9_row0_col2, #T_d73b9_row0_col3, #T_d73b9_row0_col4, #T_d73b9_row0_col5, #T_d73b9_row0_col6, #T_d73b9_row0_col7, #T_d73b9_row0_col8, #T_d73b9_row0_col9, #T_d73b9_row1_col0, #T_d73b9_row1_col1 {
#   color: red;
# }
# #T_d73b9_row0_col1, #T_d73b9_row1_col2, #T_d73b9_row1_col3, #T_d73b9_row1_col4, #T_d73b9_row1_col5, #T_d73b9_row1_col6, #T_d73b9_row1_col7, #T_d73b9_row1_col8, #T_d73b9_row1_col9 {
#   color: darkgreen;
# }
# </style>
# <table id="T_d73b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d73b9_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_d73b9_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_d73b9_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_d73b9_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_d73b9_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_d73b9_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_d73b9_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_d73b9_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_d73b9_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_d73b9_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d73b9_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_d73b9_row0_col0" class="data row0 col0" >778</td>
#       <td id="T_d73b9_row0_col1" class="data row0 col1" >-0.218</td>
#       <td id="T_d73b9_row0_col2" class="data row0 col2" >0.928</td>
#       <td id="T_d73b9_row0_col3" class="data row0 col3" >0.902</td>
#       <td id="T_d73b9_row0_col4" class="data row0 col4" >0.341</td>
#       <td id="T_d73b9_row0_col5" class="data row0 col5" >0.544</td>
#       <td id="T_d73b9_row0_col6" class="data row0 col6" >16.7</td>
#       <td id="T_d73b9_row0_col7" class="data row0 col7" >0.61</td>
#       <td id="T_d73b9_row0_col8" class="data row0 col8" >0.588</td>
#       <td id="T_d73b9_row0_col9" class="data row0 col9" >0.588</td>
#     </tr>
#     <tr>
#       <th id="T_d73b9_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_d73b9_row1_col0" class="data row1 col0" >778</td>
#       <td id="T_d73b9_row1_col1" class="data row1 col1" >-0.235</td>
#       <td id="T_d73b9_row1_col2" class="data row1 col2" >0.838</td>
#       <td id="T_d73b9_row1_col3" class="data row1 col3" >0.805</td>
#       <td id="T_d73b9_row1_col4" class="data row1 col4" >0.256</td>
#       <td id="T_d73b9_row1_col5" class="data row1 col5" >0.444</td>
#       <td id="T_d73b9_row1_col6" class="data row1 col6" >13.6</td>
#       <td id="T_d73b9_row1_col7" class="data row1 col7" >0.522</td>
#       <td id="T_d73b9_row1_col8" class="data row1 col8" >0.559</td>
#       <td id="T_d73b9_row1_col9" class="data row1 col9" >0.543</td>
#     </tr>
#   </tbody>
# </table>
# JdF_east
# <style type="text/css">
# #T_4ba57_row0_col0, #T_4ba57_row0_col2, #T_4ba57_row0_col3, #T_4ba57_row0_col4, #T_4ba57_row0_col5, #T_4ba57_row0_col6, #T_4ba57_row0_col8, #T_4ba57_row1_col0, #T_4ba57_row1_col1, #T_4ba57_row1_col7, #T_4ba57_row1_col9 {
#   color: red;
# }
# #T_4ba57_row0_col1, #T_4ba57_row0_col7, #T_4ba57_row0_col9, #T_4ba57_row1_col2, #T_4ba57_row1_col3, #T_4ba57_row1_col4, #T_4ba57_row1_col5, #T_4ba57_row1_col6, #T_4ba57_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_4ba57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ba57_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_4ba57_level0_col1" class="col_heading level0 col1" >bias</th>
#       <th id="T_4ba57_level0_col2" class="col_heading level0 col2" >rmse</th>
#       <th id="T_4ba57_level0_col3" class="col_heading level0 col3" >crmse</th>
#       <th id="T_4ba57_level0_col4" class="col_heading level0 col4" >swillmott</th>
#       <th id="T_4ba57_level0_col5" class="col_heading level0 col5" >slopedev</th>
#       <th id="T_4ba57_level0_col6" class="col_heading level0 col6" >const</th>
#       <th id="T_4ba57_level0_col7" class="col_heading level0 col7" >systematic</th>
#       <th id="T_4ba57_level0_col8" class="col_heading level0 col8" >nonsystematic</th>
#       <th id="T_4ba57_level0_col9" class="col_heading level0 col9" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ba57_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_4ba57_row0_col0" class="data row0 col0" >2907</td>
#       <td id="T_4ba57_row0_col1" class="data row0 col1" >-0.351</td>
#       <td id="T_4ba57_row0_col2" class="data row0 col2" >0.637</td>
#       <td id="T_4ba57_row0_col3" class="data row0 col3" >0.531</td>
#       <td id="T_4ba57_row0_col4" class="data row0 col4" >0.281</td>
#       <td id="T_4ba57_row0_col5" class="data row0 col5" >-0.286</td>
#       <td id="T_4ba57_row0_col6" class="data row0 col6" >-9.19</td>
#       <td id="T_4ba57_row0_col7" class="data row0 col7" >0.386</td>
#       <td id="T_4ba57_row0_col8" class="data row0 col8" >0.596</td>
#       <td id="T_4ba57_row0_col9" class="data row0 col9" >-0.378</td>
#     </tr>
#     <tr>
#       <th id="T_4ba57_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_4ba57_row1_col0" class="data row1 col0" >2907</td>
#       <td id="T_4ba57_row1_col1" class="data row1 col1" >-0.394</td>
#       <td id="T_4ba57_row1_col2" class="data row1 col2" >0.569</td>
#       <td id="T_4ba57_row1_col3" class="data row1 col3" >0.41</td>
#       <td id="T_4ba57_row1_col4" class="data row1 col4" >0.204</td>
#       <td id="T_4ba57_row1_col5" class="data row1 col5" >-0.241</td>
#       <td id="T_4ba57_row1_col6" class="data row1 col6" >-7.83</td>
#       <td id="T_4ba57_row1_col7" class="data row1 col7" >0.417</td>
#       <td id="T_4ba57_row1_col8" class="data row1 col8" >0.443</td>
#       <td id="T_4ba57_row1_col9" class="data row1 col9" >-0.408</td>
#     </tr>
#   </tbody>
# </table>
