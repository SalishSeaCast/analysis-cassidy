# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
excel_file = 'citsci_nutrient_data/nutrients_v2023 for years 2015 to 2022.xlsx'
all_sheets = pd.read_excel(excel_file, sheet_name=None)
sheets = all_sheets.keys()

for sheet_name in sheets:
    sheet = pd.read_excel(excel_file, sheet_name=sheet_name)
    sheet.to_csv('citsci_nutrient_data/%s.csv' % sheet_name, index=False)

# %%
data_2022 = pd.read_csv('citsci_nutrient_data/2022.csv')
data_2022
# Out:
#      Last update: March 14, 2023 (NF)                   Unnamed: 1  \
# 0                                Crew  Schedule Date (YYYY/MON/DD)
# 1                              Baynes                  2022-Mar-13
# 2                              Baynes                  2022-Mar-13
# 3                              Baynes                  2022-Mar-13
# 4                              Baynes                  2022-Mar-13
# ...                               ...                          ...
# 1549                         Sunshine                          NaN
# 1550                         Sunshine                          NaN
# 1551                         Sunshine                          NaN
# 1552                         Sunshine                          NaN
# 1553                         Sunshine                          NaN
#
#                           Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 0     Date of Sampling (YYYY/MON/DD)  Time (Local)  Lat_reported
# ...
